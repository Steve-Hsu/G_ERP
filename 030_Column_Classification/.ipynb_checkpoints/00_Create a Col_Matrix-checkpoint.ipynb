# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('DataSource/G_ERP_Matrix_BOM_v1.csv' ,encoding = 'ISO-8859-1', index_col = 0)

# %% [markdown]
# x = data['style']

# %% [markdown]
# print(len(data.item.unique()))

# %%
style = pd.unique(x)

# %%
len(style)
# Out:
# 315

# %%
data['style'][0]
# Out:
# 'm trail mtn wb 40 jacket'

# %%
current_style = bom['style'][0]

def trim(bom):
    for style in pd.unique(bom.style):
        print(style)

# %%
bom = data

# %%
x = bom[bom['style'] == 'm trail mtn wb 40 jacket' ]['item']

# %%
l = x.tolist()

# %%
l
# Out:
# ['lm792',
#  'sotl085-pu01',
#  'lm792',
#  'sotl085-pu01',
#  'ym11-3527',
#  'l1025 sw',
#  'cifol-39 dsbyg (h3)',
#  'cfc-39 dw2w (e)         ',
#  'web-ref-8mm',
#  '1/4" elastic',
#  'pca224',
#  '10mm grosgrain ribbon',
#  '*new* 2mm shockcord ',
#  '7mm thread eyelet',
#  'rht-004',
#  'rht-009',
#  'dw-rc-001',
#  'm_t42_bd',
#  'sco-lb-adrs    ',
#  '8mm grosgrain ',
#  'ccl-094',
#  'ccl-001',
#  'po label',
#  'm-ht-app+chain',
#  'fit-ht-gen',
#  'fit-ht-ath']

# %%
col_matrix =
# Out:
#                item                                        description spec  \
# index
# 0             lm792  shell fabric at hood, above chest, lower front...  NaN
# 1      sotl085-pu01  shell fabric at hood, above chest, lower front...  NaN
# 2             lm792                   shell fabric at mid chest panels  NaN
# 3      sotl085-pu01                   shell fabric at mid chest panels  NaN
# 4         ym11-3527                                      stretch mesh   NaN
# ...             ...                                                ...  ...
# 9991       Hang tag                   Nilorn, 235B, Big Halti hang tag  NaN
# 9992       Hang tag                  Nilorn, 206B, Active Dry hang tag  NaN
# 9993       Hang tag     PrimaLoft One Hangtag#10061565, Free of charge  NaN
# 9994         Thread                                      Sewing thread  NaN
# 9995         Thread                               Top stitching thread  NaN
#
# ...
