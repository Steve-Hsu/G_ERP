# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import recall_score, precision_score, f1_score

# %%
data = pd.read_csv('Matrix/col_classify_matrix_trimed.csv' ,encoding = 'ISO-8859-1', index_col = 0)

# %%
vectorizer = CountVectorizer(stop_words='english')

# %%
item_Matrix = data[['material',  'fabric']]

# %%
new_Matrix = item_Matrix[item_Matrix.material != 0]

# %%
Matrix[600:610]['material']
# Out:
# index
# 600                                       fake down
# 601                                               e loft
# 602                                               e loft
# 603                                         topstitching
# 604                                             bartacks
# 605    metallux zipper/ antic silver finishin g5mm au...
# 606    5mm reversible vislonopen end, 1 waydu sliders...
# 607    reversed coil zip3mmnon lock, close end1 way, ...
# 608    reversed coil zip3mmnon lock, close end1 way, ...
# 609    coil zip3mmautolock, open end1 way, da sliders...
# Name: material, dtype: object

# %%
new_Matrix
# Out:
#                                                material  fabric
# 0     , lm792, shell fabric at hood, above chest, lo...       1
# 1     , sotl085-pu01, shell fabric at hood, above ch...       1
# 2     , lm792, shell fabric at mid chest panels, , , ,        1
# 3     , sotl085-pu01, shell fabric at mid chest pane...       1
# 4     , ym11-3527, stretch mesh , , , , back pocket bag       1
# ...                                                 ...     ...
# 9991  , Hang tag, Nilorn, 235B, Big Halti hang tag, ...       0
# 9992  , Hang tag, Nilorn, 206B, Active Dry hang tag,...       0
# 9993  , Hang tag, PrimaLoft One Hangtag#10061565, Fr...       0
# 9994      , Thread, Sewing thread, , , , From CoatsOpti       0
# 9995  , Thread, Top stitching thread, , , , From Coa...       0
#
# [9996 rows x 2 columns]

# %%
Matrix = new_Matrix[item_Matrix.material != 1]

# %%
Matrix
# Out:
#                                                material  fabric
# 0     , lm792, shell fabric at hood, above chest, lo...       1
# 1     , sotl085-pu01, shell fabric at hood, above ch...       1
# 2     , lm792, shell fabric at mid chest panels, , , ,        1
# 3     , sotl085-pu01, shell fabric at mid chest pane...       1
# 4     , ym11-3527, stretch mesh , , , , back pocket bag       1
# ...                                                 ...     ...
# 9991  , Hang tag, Nilorn, 235B, Big Halti hang tag, ...       0
# 9992  , Hang tag, Nilorn, 206B, Active Dry hang tag,...       0
# 9993  , Hang tag, PrimaLoft One Hangtag#10061565, Fr...       0
# 9994      , Thread, Sewing thread, , , , From CoatsOpti       0
# 9995  , Thread, Top stitching thread, , , , From Coa...       0
#
# [9996 rows x 2 columns]

# %%
all_features = vectorizer.fit_transform(Matrix.material)

# %%
vectorizer.vocabulary_
# Out:
# {'lm792': 1114,
#  'shell': 1510,
#  'fabric': 822,
#  'hood': 979,
#  'chest': 578,
#  'lower': 1131,
#  'body': 506,
#  'sleeves': 1548,
#  'facing': 826,
#  'windflap': 1867,
#  'shockcord': 1519,
#  'tunnel': 1759,
#  'self': 1494,
#  'seam': 1485,
#  'binding': 496,
#  'needed': 1205,
#  'sotl085': 1596,
#  'pu01': 1399,
#  'mid': 1173,
#  'panels': 1281,
#  'ym11': 1910,
#  '3527': 222,
#  'stretch': 1653,
#  'mesh': 1165,
#  'pocket': 1347,
#  'bag': 468,
#  'l1025': 1062,
#  'sw': 1670,
#  'non': 1217,
#  'woven': 1885,
#  'interlining': 1020,
#  'cifol': 583,
#  '39': 231,
#  'dsbyg': 729,
#  'h3': 925,
#  'coil': 606,
#  'open': 1230,
#  'end': 795,
#  'left': 1092,
#  'insert': 1010,
#  'slider': 1549,
#  'cf': 571,
#  'zipper': 1923,
#  'cfc': 572,
#  'dw2w': 742,
#  'closed': 593,
#  'web': 1842,
#  'ref': 1420,
#  '8mm': 336,
#  'reflective': 1424,
#  'puller': 1402,
#  'inside': 1013,
#  'outside': 1247,
#  'elastic': 778,
#  'cuffs': 655,
#  'hem': 961,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, Matrix.fabric, 
test_size=0.3)

# %%
classifier = MultinomialNB()

# %%
classifier.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
x = vectorizer.transform(['', 'shell fabric', '100% poliester'])

# %%
classifier.predict(x)
# Out:
# array([0, 1, 1])
