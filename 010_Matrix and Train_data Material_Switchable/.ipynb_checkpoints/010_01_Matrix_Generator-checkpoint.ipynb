# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %%
# The dataSource in this project muct be one of the two, the G_ERP_database, which is for material classification, 
# or the col_classify_matrix, which is ofr column clsassification
source = [
    'G_ERP_database_v1_title_classify_v2_Add_missed_materials_v3.csv',
    'col_classify_matrix_trimed_20200330.csv'
         ]
bom = pd.read_csv('DataSource/'+source[0] , encoding="ISO-8859-1")

# %%
# SUBJECT represents the tagert you want to find out.
# In other words, this must be the one of column name of the DataSource.
SUBJECT ='label'

# %%
bom
# Out:
#        index      brand                     style non material rows  \
# 0          0  scott usa  m trail mtn wb 40 jacket               NaN
# 1          1  scott usa  m trail mtn wb 40 jacket               NaN
# 2          2  scott usa  m trail mtn wb 40 jacket               NaN
# 3          3  scott usa  m trail mtn wb 40 jacket               NaN
# 4          4  scott usa  m trail mtn wb 40 jacket               NaN
# ...      ...        ...                       ...               ...
# 14583  14583     Britax  Original Design_Tabelle1               NaN
# 14584  14584     Britax  Original Design_Tabelle1               NaN
# 14585  14585     Britax  Original Design_Tabelle1               NaN
# 14586  14586     Britax  Original Design_Tabelle1               NaN
# 14587  14587     Britax  Original Design_Tabelle1               NaN
#
#                 item           description spec width: weight:  \
# 0              lm792                   NaN  NaN    NaN     NaN
# 1       sotl085-pu01                   NaN  NaN    NaN     NaN
# 2              lm792                   NaN  NaN    NaN     NaN
# 3       sotl085-pu01                   NaN  NaN    NaN     NaN
# 4          ym11-3527                   NaN  NaN    NaN     NaN
# ...              ...                   ...  ...    ...     ...
# 14583  Spring Toggle  Spring Toggles/2Hole  NaN    NaN     NaN
# 14584     Retro Tape     Retro Tape/W:30mm  NaN    NaN     NaN
# 14585         Velcro           Velcro-Hook  NaN    NaN     NaN
# 14586         Velcro           Velcro-Loop  NaN    NaN     NaN
# 14587      Seam Tape                   NaN  NaN    NaN     NaN
#
#                                                 position  ... box desiccant  \
# 0      shell fabric at hood, above chest, lower front...  ... NaN       NaN
# 1      shell fabric at hood, above chest, lower front...  ... NaN       NaN
# 2                       shell fabric at mid chest panels  ... NaN       NaN
# 3                       shell fabric at mid chest panels  ... NaN       NaN
# 4                                          stretch mesh   ... NaN       NaN
# ...                                                  ...  ...  ..       ...
# 14583                                                NaN  ... NaN       NaN
# 14584                                                NaN  ... NaN       NaN
# 14585                                                NaN  ... NaN       NaN
# 14586                                                NaN  ... NaN       NaN
# 14587                                                NaN  ... NaN       NaN
#
#       hangtag tape upc papper sticker swift tack outer inner
# 0           0  NaN NaN    NaN       0          0     1     0
# 1           0  NaN NaN    NaN       0          0     1     0
# 2           0  NaN NaN    NaN       0          0     1     0
# 3           0  NaN NaN    NaN       0          0     1     0
# 4           0  NaN NaN    NaN       0          0     1     0
# ...       ...  ...  ..    ...     ...        ...   ...   ...
# 14583       0  NaN NaN    NaN       0          0     1     0
# 14584       0  NaN NaN    NaN       0          0     1     0
# 14585       0  NaN NaN    NaN       0          0     1     0
# 14586       0  NaN NaN    NaN       0          0     1     0
# 14587       0  NaN NaN    NaN       0          0     1     0
#
# [14588 rows x 62 columns]

# %%
bom.head()
# Out:
#    index      brand                     style non material rows          item  \
# 0      0  scott usa  m trail mtn wb 40 jacket               NaN         lm792
# 1      1  scott usa  m trail mtn wb 40 jacket               NaN  sotl085-pu01
# 2      2  scott usa  m trail mtn wb 40 jacket               NaN         lm792
# 3      3  scott usa  m trail mtn wb 40 jacket               NaN  sotl085-pu01
# 4      4  scott usa  m trail mtn wb 40 jacket               NaN     ym11-3527
#
#   description spec width: weight:  \
# 0         NaN  NaN    NaN     NaN
# 1         NaN  NaN    NaN     NaN
# 2         NaN  NaN    NaN     NaN
# 3         NaN  NaN    NaN     NaN
# 4         NaN  NaN    NaN     NaN
#
#                                             position  ... box desiccant  \
# 0  shell fabric at hood, above chest, lower front...  ... NaN       NaN
# 1  shell fabric at hood, above chest, lower front...  ... NaN       NaN
# 2                   shell fabric at mid chest panels  ... NaN       NaN
# 3                   shell fabric at mid chest panels  ... NaN       NaN
# 4                                      stretch mesh   ... NaN       NaN
#
#   hangtag tape upc papper sticker swift tack outer inner
# 0       0  NaN NaN    NaN       0          0     1     0
# 1       0  NaN NaN    NaN       0          0     1     0
# 2       0  NaN NaN    NaN       0          0     1     0
# 3       0  NaN NaN    NaN       0          0     1     0
# 4       0  NaN NaN    NaN       0          0     1     0
#
# [5 rows x 62 columns]

# %% [markdown]
# bom

# %%
bom_matrix = pd.DataFrame(bom[SUBJECT])

# %%
bom_matrix.insert(0, 'material', '', allow_duplicates = False)

# %%
bom_matrix
# Out:
#       material  label
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...        ...    ...
# 14583               0
# 14584               0
# 14585               0
# 14586               0
# 14587               0
#
# [14588 rows x 2 columns]

# %%
title = bom['non material rows']
item = bom['item']
description = bom['description']
spec = bom['spec']
width = bom['width:']
weight = bom['weight:']
position = bom['position']
# colorway_1 = bom['colorway-1']
# colorway_2 = bom['colorway-2']
# colorway_3 = bom['colorway-3']
# colorway_4 = bom['colorway-4']
# colorway_5 = bom['colorway-5']
# colorway_6 = bom['colorway-6']
# colorway_7 = bom['colorway-7']
# colorway_8 = bom['colorway-8']

# %%
col_list = [title,
            item, 
            description, 
            spec, width, 
            weight, position,]

# %%
type(col_list)
# Out:
# list

# %% [markdown]
# * Loop through the list to add the strings into col 'material' of dataFrame 'fabric"

# %%
x = 0
for col in col_list:
    bom_matrix['material'] = bom_matrix['material'].str.cat(col, sep =', ', na_rep='')
    x = x + 1

# %%
bom_matrix
# Out:
#                                                 material  label
# 0      , , lm792, , , , , shell fabric at hood, above...      0
# 1      , , sotl085-pu01, , , , , shell fabric at hood...      0
# 2      , , lm792, , , , , shell fabric at mid chest p...      0
# 3      , , sotl085-pu01, , , , , shell fabric at mid ...      0
# 4                   , , ym11-3527, , , , , stretch mesh       0
# ...                                                  ...    ...
# 14583    , , Spring Toggle, Spring Toggles/2Hole, , , ,       0
# 14584          , , Retro Tape, Retro Tape/W:30mm, , , ,       0
# 14585                    , , Velcro, Velcro-Hook, , , ,       0
# 14586                    , , Velcro, Velcro-Loop, , , ,       0
# 14587                            , , Seam Tape, , , , ,       0
#
# [14588 rows x 2 columns]

# %% [markdown]
# * Save the Matrix

# %%
bom_matrix.to_csv('result/Matrix/' + SUBJECT + '_matrix.csv')
