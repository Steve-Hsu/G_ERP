# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

SUBJECT ='material_garment'

# %%
bom = pd.read_csv('DataSource/G_ERP_Matrix_BOM_v5_keep_TBD.csv' , encoding="ISO-8859-1")

# %%
bom
# Out:
#        index                                  non material rows          item  \
# 0          0                                                NaN         lm792
# 1          1                                                NaN  sotl085-pu01
# 2          2                                                NaN         lm792
# 3          3                                                NaN  sotl085-pu01
# 4          4                                                NaN     ym11-3527
# ...      ...                                                ...           ...
# 14212  14212  VELCRO SUPPLIER/ REFERENCE NUMBER LOCATION AMOUNT           NaN
# 14213  14213             THREAD SPI SUPPLIER/ REF NUMBER AMOUNT           NaN
# 14214  14214  LABELS  SUPPLIER/ REFERENCE NUMBER LOCATION AM...           NaN
# 14215  14215  HANG TAGS SUPPLIER/ REFERENCE NUMBER LOCATION ...           NaN
# 14216  14216  CARE AND CONTENT LABELS SUPPLIER/ REFERENCE NU...           NaN
#
#                                              description spec width: weight:  \
# 0      shell fabric at hood, above chest, lower front...  NaN    NaN     NaN
# 1      shell fabric at hood, above chest, lower front...  NaN    NaN     NaN
# 2                       shell fabric at mid chest panels  NaN    NaN     NaN
# 3                       shell fabric at mid chest panels  NaN    NaN     NaN
# 4                                          stretch mesh   NaN    NaN     NaN
# ...                                                  ...  ...    ...     ...
# 14212                                                NaN  NaN    NaN     NaN
# 14213                                                NaN  NaN    NaN     NaN
# 14214                                                NaN  NaN    NaN     NaN
# 14215                                                NaN  NaN    NaN     NaN
# 14216                                                NaN  NaN    NaN     NaN
#
#               position        colorway-1  colorway-2  ... price/unit  unit  \
# 0                  NaN      eclipse blue    sea blue  ...          5  yard
# 1                  NaN               NaN         NaN  ...          3  yard
# 2                  NaN  tangerine orange  blue coral  ...          5  yard
# 3                  NaN               NaN         NaN  ...          3  yard
# 4      back pocket bag         dark grey   dark grey  ...        2.7  yard
# ...                ...               ...         ...  ...        ...   ...
# 14212              NaN               NaN         NaN  ...        NaN   NaN
# 14213              NaN               NaN         NaN  ...        NaN   NaN
# 14214              NaN               NaN         NaN  ...        NaN   NaN
# 14215              NaN               NaN         NaN  ...        NaN   NaN
# 14216              NaN               NaN         NaN  ...        NaN   NaN
#
#            brand                     style material_garment fabric trims  \
# 0      scott usa  m trail mtn wb 40 jacket                1      1     0
# 1      scott usa  m trail mtn wb 40 jacket                1      1     0
# 2      scott usa  m trail mtn wb 40 jacket                1      1     0
# 3      scott usa  m trail mtn wb 40 jacket                1      1     0
# 4      scott usa  m trail mtn wb 40 jacket                1      1     0
# ...          ...                       ...              ...    ...   ...
# 14212      Nitro                       NaN                0      0     0
# 14213      Nitro                       NaN                0      0     0
# 14214      Nitro                       NaN                0      0     0
# 14215      Nitro                       NaN                0      0     0
# 14216      Nitro                       NaN                0      0     0
#
#       zipper outer inner
# 0          0     1     0
# 1          0     1     0
# 2          0     1     0
# 3          0     1     0
# 4          0     1     0
# ...      ...   ...   ...
# 14212      0     0     0
# 14213      0     0     0
# 14214      0     0     0
# 14215      0     0     0
# 14216      0     0     0
#
# [14217 rows x 29 columns]

# %%
bom.head()
# Out:
#    index non material rows          item  \
# 0      0               NaN         lm792
# 1      1               NaN  sotl085-pu01
# 2      2               NaN         lm792
# 3      3               NaN  sotl085-pu01
# 4      4               NaN     ym11-3527
#
#                                          description spec width: weight:  \
# 0  shell fabric at hood, above chest, lower front...  NaN    NaN     NaN
# 1  shell fabric at hood, above chest, lower front...  NaN    NaN     NaN
# 2                   shell fabric at mid chest panels  NaN    NaN     NaN
# 3                   shell fabric at mid chest panels  NaN    NaN     NaN
# 4                                      stretch mesh   NaN    NaN     NaN
#
#           position        colorway-1  colorway-2  ... price/unit  unit  \
# 0              NaN      eclipse blue    sea blue  ...          5  yard
# 1              NaN               NaN         NaN  ...          3  yard
# 2              NaN  tangerine orange  blue coral  ...          5  yard
# 3              NaN               NaN         NaN  ...          3  yard
# 4  back pocket bag         dark grey   dark grey  ...        2.7  yard
#
#        brand                     style material_garment fabric trims zipper  \
# 0  scott usa  m trail mtn wb 40 jacket                1      1     0      0
# 1  scott usa  m trail mtn wb 40 jacket                1      1     0      0
# 2  scott usa  m trail mtn wb 40 jacket                1      1     0      0
# 3  scott usa  m trail mtn wb 40 jacket                1      1     0      0
# 4  scott usa  m trail mtn wb 40 jacket                1      1     0      0
#
#   outer inner
# 0     1     0
# 1     1     0
# 2     1     0
# 3     1     0
# 4     1     0
#
# [5 rows x 29 columns]

# %% [markdown]
# bom

# %%
bom_matrix = pd.DataFrame(bom[SUBJECT])

# %%
bom_matrix.insert(0, 'material', '', allow_duplicates = False)

# %%
bom_matrix
# Out:
#       material  material_garment
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
# ...        ...               ...
# 14212                          0
# 14213                          0
# 14214                          0
# 14215                          0
# 14216                          0
#
# [14217 rows x 2 columns]

# %%
title = bom['non material rows']
item = bom['item']
description = bom['description']
spec = bom['spec']
width = bom['width:']
weight = bom['weight:']
position = bom['position']
# colorway_1 = bom['colorway-1']
# colorway_2 = bom['colorway-2']
# colorway_3 = bom['colorway-3']
# colorway_4 = bom['colorway-4']
# colorway_5 = bom['colorway-5']
# colorway_6 = bom['colorway-6']
# colorway_7 = bom['colorway-7']
# colorway_8 = bom['colorway-8']

# %%
col_list = [title,
            item, 
            description, 
            spec, width, 
            weight, position,]

# %% [markdown]
# * Loop through the list to add the strings into col 'material' of dataFrame 'fabric"

# %%
x = 0
for col in col_list:
    bom_matrix['material'] = bom_matrix['material'].str.cat(col, sep =', ', na_rep='')
    x = x + 1

# %%
bom_matrix
# Out:
#                                                 material  material_garment
# 0      , , lm792, shell fabric at hood, above chest, ...                 1
# 1      , , sotl085-pu01, shell fabric at hood, above ...                 1
# 2      , , lm792, shell fabric at mid chest panels, ,...                 1
# 3      , , sotl085-pu01, shell fabric at mid chest pa...                 1
# 4      , , ym11-3527, stretch mesh , , , , back pocke...                 1
# ...                                                  ...               ...
# 14212  , VELCRO SUPPLIER/ REFERENCE NUMBER LOCATION A...                 0
# 14213  , THREAD SPI SUPPLIER/ REF NUMBER AMOUNT, , , ...                 0
# 14214  , LABELS  SUPPLIER/ REFERENCE NUMBER LOCATION ...                 0
# 14215  , HANG TAGS SUPPLIER/ REFERENCE NUMBER LOCATIO...                 0
# 14216  , CARE AND CONTENT LABELS SUPPLIER/ REFERENCE ...                 0
#
# [14217 rows x 2 columns]

# %% [markdown]
# * Save the Matrix

# %%
bom_matrix.to_csv('result/Matrix/' + SUBJECT + '_matrix.csv')
