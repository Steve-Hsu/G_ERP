# %%
import pandas as pd
import numpy as np

# %%
eider_ex = pd.read_excel('DataSource/DT_THE ROCKS JKT 2.0M_EIV4414_FW1819 (2018-1-24 comments -3).xlsx', sheet_name='FABRIC')
ride_ex = pd.read_excel('DataSource/18M20-07 BOM 170525.xlsx')

# %%
eider_ex.to_csv('DataSource/eider_Turned_csv.csv')
ride_ex.to_csv('DataSource/ride_Turned_csv.csv')

# %%
eider_csv = pd.read_csv('DataSource/eider_Turned_csv.csv', index_col = 0)
ride_csv = pd.read_csv('DataSource/ride_Turned_csv.csv', index_col = 0)

# %%
ride_csv
# Out:
#      BILL OF MATERIALS           Unnamed: 1  \
# 0                BUYER                  NaN
# 1               SERIES                  20K
# 2               SEASON          Winter 1819
# 3                 DATE  2020-01-03 00:00:00
# 4         RIDE STYLE #             18M20-07
# ..                 ...                  ...
# 91  Main Ride hang tag                  NaN
# 92            Poly Bag                  NaN
# 93       Content Label                  NaN
# 94          Wash Label                  NaN
# 95          Poly Label                  NaN
#
#                                            Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                 NaN        NaN        NaN
# 1                                                 NaN        NaN        NaN
# 2                                                 NaN        NaN        NaN
# 3                                                 NaN        NaN        NaN
# ...
