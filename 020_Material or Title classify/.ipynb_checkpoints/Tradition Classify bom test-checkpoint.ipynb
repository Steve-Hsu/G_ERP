# %%
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from sklearn.model_selection import train_test_split

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Switch area
SUBJECT = 'fabric'
VOCAB_SIZE = 900

# %%
BOM = 'DataSource/AB18MJ1_032_BOM.xlsx'
Matrix = 'Matrix/fabric_matrix.csv'

# %%
bom = pd.read_excel(BOM)

# %%
bom
# Out:
#         AIRBLASTER         Unnamed: 1  \
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3      Style Name:                NaN
# 4   Toaster Jacket                NaN
# ..             ...                ...
# 61               3  ZIPPER DIRECTION:
# 62               4           BARTACK:
# 63               5          HEAT CUT:
# 64               6    GROMMETS/SNAPS:
# 65               7      THREAD COLOR:
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                         Insulation:
# 3                                              Seams:
# 4                                          MM Rating:
# ..                                                ...
# 61  CF has right hand slider, pocket zippers close...
# 62                                   At stress points
# 63                          Elastic, webbing, taffeta
# 64                         Should have pellon backing
# 65           Matches fabric color, unless noted above
#
#                         Unnamed: 3 Unnamed: 4 Style Number: AB18MJ1_032  \
# 0                              NaN        NaN            Designer:   JG
# 1                              NaN        NaN    Season: Winter 2017/18
# 2   100gm in the body hood sleeves        NaN       Collection: Freedom
# 3                 Critically Taped        NaN            Vendor: Soluna
# 4                              NaN        NaN                       NaN
# ..                             ...        ...                       ...
# 61                             NaN        NaN                       NaN
# 62                             NaN        NaN                       NaN
# 63                             NaN        NaN                       NaN
# 64                             NaN        NaN                       NaN
# 65                             NaN        NaN                       NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0         NaN        NaN        NaN        NaN          NaN          NaN
# 1         NaN        NaN        NaN        NaN          NaN          NaN
# 2         NaN        NaN        NaN        NaN          NaN          NaN
# 3         NaN        NaN        NaN        NaN          NaN          NaN
# 4         NaN        NaN        NaN        NaN          NaN          NaN
# ..        ...        ...        ...        ...          ...          ...
# 61        NaN        NaN        NaN        NaN          NaN          NaN
# 62        NaN        NaN        NaN        NaN          NaN          NaN
# 63        NaN        NaN        NaN        NaN          NaN          NaN
# 64        NaN        NaN        NaN        NaN          NaN          NaN
# 65        NaN        NaN        NaN        NaN          NaN          NaN
#
#     Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 61          NaN          NaN          NaN          NaN          NaN
# 62          NaN          NaN          NaN          NaN          NaN
# 63          NaN          NaN          NaN          NaN          NaN
# 64          NaN          NaN          NaN          NaN          NaN
# 65          NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 17  Unnamed: 18
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# ..          ...          ...
# 61          NaN          NaN
# 62          NaN          NaN
# 63          NaN          NaN
# 64          NaN          NaN
# 65          NaN          NaN
#
# [66 rows x 19 columns]

# %% [markdown]
# ## The classify function
# * Check each row and return the index, if it is classified as True

# %%
def classify_series(series):
    index_list = []
    for word in series:
        x = [word]
        judge = vectorizer.transform(x)
        if  classifier.predict(judge) == 1:
            index_list.append(series[series == word].index[0])
        
    return index_list## Walk through bom

# %% [markdown]
# ## Walk through bom
# * Parse a xlsm of bom, turn the row into a col.
# * Put the col to the classify function
# * Return the index of row that is True

# %%
def check_index(xlsx_path):
    '''
    
    The parameter of the func is the path of bom in xlsx format
    
    '''
    bom = pd.read_excel(xlsx_path)
    database = []
    
    for row in bom.index:
        row_str = str()
        for col in bom:
            row_str = row_str + ', ' + str(bom.at[row, col])
        database.append(row_str)
    
    col = pd.Series(database)
#     index_list = classify_series(col)
    
    return col

# %%
check_index(BOM)
# Out:
# 0     , nan, nan, nan, nan, nan, Designer:   JG, nan...
# 1     , nan, nan, nan, nan, nan, Season: Winter 2017...
# 2     , nan, nan, Insulation:, 100gm in the body hoo...
# 3     , Style Name:, nan, Seams:, Critically Taped, ...
# 4     , Toaster Jacket, nan, MM Rating:, nan, nan, n...
#                             ...
# 61    , 3, ZIPPER DIRECTION:, CF has right hand slid...
# 62    , 4, BARTACK:, At stress points, nan, nan, nan...
# 63    , 5, HEAT CUT:, Elastic, webbing, taffeta, nan...
# 64    , 6, GROMMETS/SNAPS:, Should have pellon backi...
# 65    , 7, THREAD COLOR:, Matches fabric color, unle...
# Length: 66, dtype: object
