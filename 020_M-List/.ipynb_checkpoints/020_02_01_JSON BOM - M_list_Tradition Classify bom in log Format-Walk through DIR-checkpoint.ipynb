# %%
import pandas as pd
import numpy as np

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


from sklearn.model_selection import train_test_split

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# File system
from os import walk
from os.path import join

# Switch area
SUBJECT = 'material_garment'
VOCAB_SIZE = 900
SHEET_NAME_LIST = ['bom', 'trims', 'shell', 'fabric', 'accessories', 'spec', '228184', '#334183', 'tabelle1']
# FILE_NAME = 'Ride_18M20-01'

# %%
FROM_DIR = 'DataSource/Original_BOM'
TO_DIR = 'result'
# BOM = 'DataSource/'+ FILE_NAME + '.xlsx'
VOCAB = 'DataSource/Trained Data/' + SUBJECT + '_vocabulary.csv'
TRAIN_DATA_0 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_0_in_train_data'
TRAIN_DATA_1 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_1_in_train_data'
TRAIN_DATA_ALL =  'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_all_in_train_data'
PROB_1_TRAIN_DATA = 'DataSource/Trained Data/' + SUBJECT + '_prob_ctg_1_in_train_data'

# %% [markdown]
# # Functions

# %% [markdown]
# ## delete_col()
# * Delete the none columns

# %%
def delete_col(bom):
    for col in bom:
        if bom[col].count() == 0:
            bom = bom.drop(col, axis = 1)
        
    return bom

# %% [markdown]
# ## stemmered_nltk_convert()
# * Nltk stemmered Function

# %%
def stemmered_nltk_convert(col_of_df):
    '''
    Parameter of this function is a column of a dataFrame.
    
    '''
    # difine Stop words
    stop_words = set(stopwords.words('english'))
    # Difine Stemmer
    stemmer = SnowballStemmer('english')
    
    # converts to lower case and splits up the words
    words = word_tokenize(col_of_df)
    filtered_words = []
    
    for word in words:
        # Removes the stop words and punctuation
        # if word is not in the stop_words list and is not a alpha.
        if word not in stop_words and word.isalpha():
            filtered_words.append(stemmer.stem(word))
            
    return filtered_words

# %% [markdown]
# ## turn_series()
# #### Walk through bom
# * Parse a xlsm of bom, turn the row into a cell, all the cells will form a col.
# * Put the cell to the classify function
# * Return the index of row that is True

# %%
def turn_series(bom):
    '''
    
    The parameter of the func is a dataFrame
    
    '''
    database = []
    
    for row in bom.index:
        row_str = str()
        for col in bom:
            row_str = row_str + ', ' + str(bom.at[row, col])
        database.append(row_str)
    
    col = pd.Series(database)
#     index_list = classify_series(col)
    
    return col

# %% [markdown]
# ## make_sparse_matrix()
# ### Sparse Matrix Function
# * Create a sparse Matrix for the data we want to predict
# * The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.

# %%
def make_sparse_matrix(df, vocabulary):
    """
    Param1:
    The data we want to sparse, which must be in format of DataFrame.
    Param2:
    The vocabulary, it is generated when we training datas.
    
    Returns a sparse matrix as dataframe
    """
 
    indexed_words = pd.Index(vocabulary.VOCAB_WORD)
    nr_rows = df.shape[0]
    nr_cols = df.shape[1]
    word_set = set(indexed_words)
    dict_list = []
    
    for i in range(nr_rows):
        for j in range(nr_cols):
            
            word = df.iat[i, j]
            if word in word_set:
                doc_id = df.index[i]
                word_id = indexed_words.get_loc(word)
                
                item = {'MATERIAL_ID': doc_id,
                       'OCCURENCE': 1, 'WORD_ID': word_id}
                
                dict_list.append(item)
                
    return pd.DataFrame(dict_list)

# %% [markdown]
# ## make_full_feature()
# ### Full Matrix
# * Since we want to predict the data, so we create the Full Feature directly.

# %%
def make_full_feature(sparse_matrix, nr_words, doc_idx = 0, word_idx = 1, freq_idx = 2):
    column_names = ['MATERIAL_ID'] + list(range(0, VOCAB_SIZE))
    doc_id_names = np.unique(sparse_matrix[:,0])
    full_matrix = pd.DataFrame(index = doc_id_names, columns = column_names)
    full_matrix.fillna(value=0, inplace=True)
    
    for i in range(sparse_matrix.shape[0]):
        doc_nr = sparse_matrix[i][doc_idx]
        word_id = sparse_matrix[i][word_idx]
        occurrence = sparse_matrix[i][freq_idx]
        
        full_matrix.at[doc_nr, 'MATERIAL_ID'] = doc_nr
        full_matrix.at[doc_nr, word_id] = occurrence
        
    full_matrix.set_index('MATERIAL_ID', inplace = True)
    return full_matrix

# %% [markdown]
# # Main Funciton
# ## M-List_generator
# * Pick up material rows from a bom of xlsx and form it a dataFrame

# %%
def material_list_generator(JSONbom,
                            VOCAB='DataSource/Trained Data/' + SUBJECT + '_vocabulary.csv',
                            TRAIN_DATA_1='DataSource/Trained Data/' +
                            SUBJECT + '_prob_tokens_ctg_1_in_train_data',
                            TRAIN_DATA_0='DataSource/Trained Data/' +
                            SUBJECT + '_prob_tokens_ctg_0_in_train_data',
                            TRAIN_DATA_ALL='DataSource/Trained Data/' +
                            SUBJECT + '_prob_tokens_all_in_train_data',
                            PROB_1_TRAIN_DATA='DataSource/Trained Data/' + SUBJECT + '_prob_ctg_1_in_train_data'):
    '''
    Param_1
    Bom in JSON format, JSON is an array, the rows is an array under the JSON array.

    Param_2
    The path of the vocabulary
    Token list with WORD_ID

    Param_3
    The trained data of catagory True
    Probabilitie of each token in category True

    Param_4
    The trained data of category False
    Probabilitie of each token in category False

    Param_5
    The trained data of category both.
    Probabilitie of each token in all documents

    Param_6
    The percentage of documents in catagory True in all documents.
    Number of documents in catagory True / number of all documents
    '''
    # read the vocabulary
    vocab = pd.read_csv(VOCAB, index_col=0)
    # read the trained_datas
    train_data_1 = np.loadtxt(TRAIN_DATA_1)
    train_data_0 = np.loadtxt(TRAIN_DATA_0)
    train_data_all = np.loadtxt(TRAIN_DATA_ALL)
    prob_ctg_1 = pd.read_csv(PROB_1_TRAIN_DATA, index_col=0)
    prob_ctg_1_train_data = prob_ctg_1.loc[0, 'prob_ctg_1_train_set']

    # Read JSON
    bom = pd.read_json(JSONbom)

    # Delete useless cols
    col_deleted_bom = delete_col(bom)

    # Series
    # Parse the bom, make each col getting together to be 1 col
    new_bom = turn_series(col_deleted_bom)

    # nltk_convert
    stemmed_bom = new_bom.apply(stemmered_nltk_convert)

    # Convert the stemmed series into df
    # 1 token get 1 cell
    word_col_df = pd.DataFrame.from_records(stemmed_bom.tolist())

    # Sparse Matrix
    # Create a sparse Matrix for the data we want to predict
    # The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.
    sparse_predict_df = make_sparse_matrix(word_col_df, vocab)
    # Grouped by MATERIAL_ID
    sparse_predict_df_grouped = sparse_predict_df.groupby(
        ['MATERIAL_ID', 'WORD_ID']).sum()
    # Reset it index
    sparse_predict_df_grouped = sparse_predict_df_grouped.reset_index()
    # Convert it into numpy array.
    sparse_predict_data = sparse_predict_df_grouped.to_numpy()

    # Full Matrix
    predict_full_feature = make_full_feature(
        sparse_predict_data, vocab.shape[0])

    # Joint probability in log format
    joint_log_ctg_1 = predict_full_feature.dot(
        np.log(train_data_1) - np.log(train_data_all)) + np.log(prob_ctg_1_train_data)
    joint_log_ctg_0 = predict_full_feature.dot(
        np.log(train_data_0)-np.log(train_data_all))+np.log(1 - prob_ctg_1_train_data)
    # Prediction
    prediction_log = joint_log_ctg_1 > joint_log_ctg_0

    # Get the index of the row that predicted as material in the bom
    row_list = prediction_log[prediction_log == True].index

    # Get the material from the original bom by the index in row_list
    material_list = bom.loc[row_list, :]

    return material_list

# %%
 JSONResult = material_list_generator(JSON_BOM)
print(JSONResult)
 JSONResult.to_csv('result/JSON_TEST_material_list.csv')
# Out:
#                 0                                                  1  \
# MATERIAL_ID
# 3            None                                               None
# 9            None                                               None
# 10              A                                       Shell Fabric
# 11              B                                       Shell Fabric
# 12              C                                             Lining
# 13              D                                              Other
# 14              E                                              Other
# 15              F                                              Other
# 16              G                                              Other
# 17              H                                              Other
# 18              I                                              Other
# 19              J                                             Pellon
# 20              K                                             Pellon
# 22              L                                               None
# 23             AA                                             Zipper
# 24             BB                                             Zipper
# 25             CC                                             Zipper
# 26             DD                                             Zipper
# 27             EE                                        Zipper Pull
# 30             FF                                           Stoppers
# 31             GG                                           Stoppers
# 32             HH                                         Hand Pulls
# 33             II                                            Webbing
# 34             JJ                                            Webbing
# 35             KK                                           Hardware
# 36             LL                                           Hardware
# 37             MM                                           Hardware
# 38             NN                                           Drawcord
# 39             OO                                   Elastic Drawcord
# 40             PP                                           Key Clip
# 41             QQ                                         Main Label
# 42             RR                                         Size Label
# 43             SS                                          W/C Label
# 44             TT                               ABWVLP_01 Woven loop
# 45             VV                                           Branding
# 48             WW                                            HANGTAG
# 49             XX                                            HANGTAG
# 50             YY                          polybag w/ warning matter
# 51             ZZ  Country of Origin sticker (supplied by your side)
# 52            AAA                UPC sticker (supplied by your side)
# 56              3                                  ZIPPER DIRECTION:
# 58              5                                          HEAT CUT:
#
#                                                              2  \
# MATERIAL_ID
# 3                                                  Insulation:
# 9                                                         None
# 10           SOTD109-C1-Y 100% Polyester 10K/8K 10K/8K +2-L...
# 11           SOTP069-C1-H 100% Polyester 10K/8K 15k/10k+2-L...
# 12           210T-E EMB07 Terry Emboss Taffeta (Supplied by...
# 13              Velvety Tricot - SOTO048-1 (supplied by Solis)
# 14              100% poly MESH - SOTC025-1 (supplied by Solis)
# 15           nylon/elastic lycra - SONO029-1 (supplied by S...
# 16                                          Lycra binding tape
# 17                                             Gripper elastic
# 18                                             60gm Insulation
# 19                         lightweight interfacing (item# TBD)
# 20                         heavyweight interfacing (item# TBD)
# 22                                                        None
# 23           YKK No.5 coil zipper.  Auto-lock slider DA8LH,...
# 24           YKK  No.5 nylon coil zippers.  Auto-lock slide...
# 25           YKK  No.5 nylon coil zippers,1-way hidden chai...
# 26           YKK  No.5 nylon coil zippers hidden chain ,aut...
# 27           ABZP_01 Utility cord zipper pullers with tied ...
# 30                                Round Barrel stopper - K-018
# 31                                       K343-2N push stoppers
# 32                                     Plastic hand pulls ZP11
# 33                                      Flat Webbing Tape, 8mm
# 34                                 flat webbing tape 8mm width
# 35                         metal eyelets, 12mm (incl. washers)
# 36           Snap Buttons ABSNP_01 (sets), 17mm (incl. wash...
# 37                              Male snap only (incl. washers)
# 38           Flat Shoelace drawcord WITH Black Oxidize fini...
# 39                                         2.5 mm elastic cord
# 40                  plastic key clip attched with webbing loop
# 41                                  ABWV_67 Freedom Main Label
# 42                                 ABWV_69V Vietnam Size Label
# 43                                      Satin Label with print
# 44                                 ABWVLP_01 (Supplied by SML)
# 45                                      ABPA_22 Workwear Label
# 48                                                         TBD
# 49                                                         TBD
# 50                                  Airpill Logo Print:  16 cm
# 51                                       Made in China sticker
# 52                                        Sticker width 3.5 cm
# 56           CF has right hand slider, pocket zippers close...
# 58                                   Elastic, webbing, taffeta
#
#                                                              3  \
# MATERIAL_ID
# 3                          60gm Insulation at body sleeve,hood
# 9                                                         None
# 10                         Main body, sleeves, collar, pockets
# 11                                                        Hood
# 12                     Inside lining, powder skirt, pocket bag
# 13            Comfort chin guard, inner front pocket bag panel
# 14                               vents, internal goggle pocket
# 15                                  powder skirt, wrist gators
# 16                                Internal mesh pocket opening
# 17                                                powder skirt
# 18                                     Main body hood, sleeves
# 19                Inner storm flap, powder skirt closure flaps
# 20                                                   hood brim
# 22                                                        None
# 23                                                        C.F.
# 24                                           ( 2) hand pockets
# 25                                                       vents
# 26                       1 internal pocket at w.'s inside LEFT
# 27           (2) pockets, (1) C.F. (2) vents,  (1) inside p...
# 30                                                    (2) hood
# 31                                              (2) bottom hem
# 32                                              (2) bottom hem
# 33           key clip attachment at inside wearer's right p...
# 34                  (2)Stopper attachments loops at bottom hem
# 35                 (4) at hood opening,  (4) inside bottom hem
# 36           (6) C.F., (2) cuffs, (1) snap tabs at inside b...
# 37                                  (2) powder skirt (2) cuffs
# 38                                                        hood
# 39                                       bottom hem adjustment
# 40                                Inside wearers right pocket.
# 41                     inside c.b. neck, see Q/A for placement
# 42                       sewn in and centered below main label
# 43           wearer's left side seam, 10 cm up from bottom ...
# 44                                inside center back neck seam
# 45               LEFT chest, see art placement page for detail
# 48                                                         TBD
# 49                                                         TBD
# 50                                        centered on poly bag
# 51                                  Centered above UPC sticker
# 52                                 Lookers right bottom corner
# 56                                                        None
# 58                                                        None
#
#                              4                      5                      6  \
# MATERIAL_ID
# 3                         None    Collection: Freedom                   None
# 9            FABRICS & LININGS                   None                   None
# 10                        None                  BLACK            KOMBU GREEN
# 11                        None                  CAMEL                  BLACK
# 12                        None                  BLACK                  BLACK
# 13                        None                  BLACK                  BLACK
# 14                        None                  BLACK                  BLACK
# 15                        None                  BLACK                  BLACK
# 16                        None                  BLACK                  BLACK
# 17                        None                  BLACK                  BLACK
# 18                        None                   None                   None
# 19                        None                  WHITE                  WHITE
# 20                        None                  WHITE                  WHITE
# 22                     ZIPPERS                   None                   None
# 23                           1              CAMEL 161                  BLACK
# 24                           2              CAMEL 161                  BLACK
# 25                           2              CAMEL 161                  BLACK
# 26                           1              CAMEL 161                  BLACK
# 27                           6                  BLACK                  BLACK
# 30                           2                  BLACK                  BLACK
# 31                           2                  BLACK                  BLACK
# 32                           2                  BLACK                  BLACK
# 33                           1                  BLACK                  BLACK
# 34                           2                  BLACK                  BLACK
# 35                           8  DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18
# 36                          11  DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18
# 37                           4  DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18
# 38                           1                  BLACK                  BLACK
# 39                           1                  BLACK                  BLACK
# 40                           1                  BLACK                  BLACK
# 41                           1             GOLD/BLACK             GOLD/BLACK
# 42                           1             BLACK/GOLD             BLACK/GOLD
# 43                           1                  BLACK                  BLACK
# 44                           1             BLACK/GOLD             BLACK/GOLD
# 45                           1                  BROWN                  BROWN
# 48                           1                    TBD                    TBD
# 49                           1                    TBD                    TBD
# 50                           1                  CLEAR                  CLEAR
# 51                           1                    TBD                    TBD
# 52                           1                    TBD                    TBD
# 56                        None                   None                   None
# 58                        None                   None                   None
#
#                                  7                      8            9
# MATERIAL_ID
# 3                             None                   None         None
# 9                             None                   None         None
# 10                           KHAKI              DARK NAVY  AB18MJ2_081
# 11                           BLACK                OXBLOOD  AB18MJ2_081
# 12                           BLACK                  BLACK  AB18MJ2_081
# 13                           BLACK                  BLACK  AB18MJ2_081
# 14                           BLACK                  BLACK  AB18MJ2_081
# 15                           BLACK                  BLACK  AB18MJ2_081
# 16                           BLACK                  BLACK  AB18MJ2_081
# 17                           BLACK                  BLACK  AB18MJ2_081
# 18                            None                   None  AB18MJ2_081
# 19                           WHITE                  WHITE  AB18MJ2_081
# 20                           WHITE                  WHITE  AB18MJ2_081
# 22                            None                   None  AB18MJ2_081
# 23                           BLACK            OXBLOOD 097  AB18MJ2_081
# 24                           BLACK            OXBLOOD 097  AB18MJ2_081
# 25                           BLACK            OXBLOOD 097  AB18MJ2_081
# 26                           BLACK            OXBLOOD 097  AB18MJ2_081
# 27                           BLACK                  BLACK  AB18MJ2_081
# 30                      DARK OLIVE                  BLACK  AB18MJ2_081
# 31                      DARK OLIVE                  BLACK  AB18MJ2_081
# 32                      DARK OLIVE                  BLACK  AB18MJ2_081
# 33                           BLACK                  BLACK  AB18MJ2_081
# 34                           BLACK                  BLACK  AB18MJ2_081
# 35           DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18  AB18MJ2_081
# 36           DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18  AB18MJ2_081
# 37           DARK ANTI BRASS BI-18  DARK ANTI BRASS BI-18  AB18MJ2_081
# 38                      DARK OLIVE                  BLACK  AB18MJ2_081
# 39                      DARK OLIVE                  BLACK  AB18MJ2_081
# 40                           BLACK                  BLACK  AB18MJ2_081
# 41                      GOLD/BLACK             GOLD/BLACK  AB18MJ2_081
# 42                      BLACK/GOLD             BLACK/GOLD  AB18MJ2_081
# 43                           BLACK                  BLACK  AB18MJ2_081
# 44                      BLACK/GOLD             BLACK/GOLD  AB18MJ2_081
# 45                           BROWN                  BROWN  AB18MJ2_081
# 48                             TBD                    TBD  AB18MJ2_081
# 49                             TBD                    TBD  AB18MJ2_081
# 50                           CLEAR                  CLEAR  AB18MJ2_081
# 51                             TBD                    TBD  AB18MJ2_081
# 52                             TBD                    TBD  AB18MJ2_081
# 56                            None                   None         None
# 58                            None                   None         None

# %% [markdown]
# ## Walk through a workbook
# * Check each sheet in the workbook

# %%
def sheet_checkor(BOM, Style_name, SHEET_NAME_LIST = SHEET_NAME_LIST):
    xl = pd.ExcelFile(BOM)
    
    for sheet in xl.sheet_names:
        name = str(sheet).lower()
        if any(x in name for x in SHEET_NAME_LIST): 
            bom = xl.parse(sheet, index_col = None, header = None)
            bom_list = material_list_generator(bom)
            
            # Delete empty columns
            for col in bom_list:
                if bom_list[col].count() == 0:
                    bom_list = bom_list.drop(col, axis = 1)

            bom_list.to_csv('result/' + Style_name + '_' + sheet + '_material_list.csv')
            print(name)
            
    print('Job finished')
    return

# %% [markdown]
# ## Walk through a dir
# * Check each xlsx in a dir

# %%
def material_list_convertor(FROM_DIR, TO_DIR):
    converted_xlsm_num = 0
    for root, dirnames, filenames in walk(FROM_DIR):
        # walk through each xlsx file
        for file_name in filenames:
             # get the path of the file
            # Appoint the method only work with .xlsx file.
            if file_name.endswith('.xlsx') :
                converted_xlsm_num = converted_xlsm_num + 1
                filepath = join(root, file_name)
                # Custom function
                sheet_checkor(filepath, file_name[0:-5])
    print('Converted ', converted_xlsm_num, ' files')

# %%
# %%time
# material_list_convertor(FROM_DIR, TO_DIR)
