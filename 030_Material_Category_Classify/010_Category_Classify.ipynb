# %% [markdown]
# # Category_Classify
# ## Goal of the function
# * The dataSource of the func is M-List
# * Classify the material in the M-List, and fill the new colum "Category" with string such as "Fabric", "Zipper", "Button" etc.
# * Save the result as a Categoried_M_List

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# File system
from os import walk
from os.path import join

# Switch area
# CATEGORY_LIST =['fabric', 'insulation', 'interfacing', 'zipper', 'label']
CATEGORY_LIST = ['label', 'fabric']
SUBJECT = 'label'
VOCAB_SIZE = 900

# %%
FROM_DIR = 'DataSource/M-List'
TO_DIR = 'result'

# %%
 M_List = pd.read_csv(FROM_DIR + '/AB18MJ1_032_ BOM_032 BOM_material_list.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# * df.insert(1, 'Category', '', True)
#
# * df.at[0,'Category'] = 'Steve'

# %% [markdown]
# # Functions
# * We need to convert the M_list(Type in DF)through several process to Full matrix, so we can classify the M_List with the trained_data we made before.
# ## Process
# ### delete_col()
# ### stemmered_nltk_convert()
# ### turn_series()
# ### make_sparse_matrix()
# ### make_full_feature()

# %% [markdown]
# ## delete_col()
# * Delete the none columns

# %%
def delete_col(m_list):
    for col in m_list:
        if m_list[col].count() == 0:
            m_list = m_list.drop(col, axis = 1)
        
    return m_list

# %% [markdown]
# ## stemmered_nltk_convert()
# * Nltk stemmered Function

# %%
def stemmered_nltk_convert(col_of_df):
    '''
    Parameter of this function is a column of a dataFrame.
    
    '''
    # difine Stop words
    stop_words = set(stopwords.words('english'))
    # Difine Stemmer
    stemmer = SnowballStemmer('english')
    
    # converts to lower case and splits up the words
    words = word_tokenize(col_of_df)
    filtered_words = []
    
    for word in words:
        # Removes the stop words and punctuation
        # if word is not in the stop_words list and is not a alpha.
        if word not in stop_words and word.isalpha():
            filtered_words.append(stemmer.stem(word))
            
    return filtered_words

# %% [markdown]
# ## turn_series()
# #### Walk through bom
# * Parse a xlsm of bom, turn the row into a cell, all the cells will form a col.
# * Put the cell to the classify function
# * Return the index of row that is True

# %%
def turn_series(bom):
    '''
    
    The parameter of the func is a dataFrame
    
    '''
    database = []
    
    for row in bom.index:
        row_str = str()
        for col in bom:
            row_str = row_str + ', ' + str(bom.at[row, col])
        database.append(row_str)
    
    col = pd.Series(database)
#     index_list = classify_series(col)
    
    return col

# %% [markdown]
# ## make_sparse_matrix()
# ### Sparse Matrix Function
# * Create a sparse Matrix for the data we want to predict
# * The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.

# %%
def make_sparse_matrix(df, vocabulary):
    """
    Param1:
    The data we want to sparse, which must be in format of DataFrame.
    
    Param2:
    The vocabulary, it is generated when we training datas.
    
    Returns a sparse matrix as dataframe
    """
 
    indexed_words = pd.Index(vocabulary.VOCAB_WORD)
    nr_rows = df.shape[0]
    nr_cols = df.shape[1]
    word_set = set(indexed_words)
    dict_list = []
    
    for i in range(nr_rows):
        for j in range(nr_cols):
            
            word = df.iat[i, j]
            if word in word_set:
                doc_id = df.index[i]
                word_id = indexed_words.get_loc(word)
                
                item = {'MATERIAL_ID': doc_id,
                       'OCCURENCE': 1, 'WORD_ID': word_id}
                
                dict_list.append(item)
                
    return pd.DataFrame(dict_list)

# %% [markdown]
# ## make_full_feature()
# ### Full Matrix
# * Since we want to predict the data, so we create the Full Feature directly.

# %%
def make_full_feature(sparse_matrix, nr_words, doc_idx = 0, word_idx = 1, freq_idx = 2):
    column_names = ['MATERIAL_ID'] + list(range(0, VOCAB_SIZE))
    doc_id_names = np.unique(sparse_matrix[:,0])
    full_matrix = pd.DataFrame(index = doc_id_names, columns = column_names)
    full_matrix.fillna(value=0, inplace=True)
    
    for i in range(sparse_matrix.shape[0]):
        doc_nr = sparse_matrix[i][doc_idx]
        word_id = sparse_matrix[i][word_idx]
        occurrence = sparse_matrix[i][freq_idx]
        
        full_matrix.at[doc_nr, 'MATERIAL_ID'] = doc_nr
        full_matrix.at[doc_nr, word_id] = occurrence
        
    full_matrix.set_index('MATERIAL_ID', inplace = True)
    return full_matrix

# %% [markdown]
# # Core Funciton
# ## Material_Classifor
# * Classifor the materials in the M-List,
# * Mateiral is in row direction in a M-List.
# * Return a list of index of row that classified as "true"

# %%
def material_classifor(bom, 
                       VOCAB  = 'DataSource/Trained Data/' + SUBJECT + '_vocabulary.csv', 
                       TRAIN_DATA_1 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_1_in_train_data',
                       TRAIN_DATA_0 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_0_in_train_data', 
                       TRAIN_DATA_ALL = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_all_in_train_data', 
                       PROB_1_TRAIN_DATA = 'DataSource/Trained Data/' + SUBJECT + '_prob_ctg_1_in_train_data' ):
    '''
    Param_1
    <bom>
    DataFrame, by reading M-List in csv format.
    
    Param_2
    <VOCAB>
    The path of the vocabulary
    Token list with WORD_ID
    
    Param_3
    <TRAIN_DATA_1>
    The trained data of catagory True
    Probabilitie of each token in category True
    
    Param_4
    <TRAIN_DATA_0>
    The trained data of category False
    Probabilitie of each token in category False
    
    Param_5
    <TRAIN_DATA_ALL>
    The trained data of category both.
    Probabilitie of each token in all documents
    
    Param_6
    <PROB_1_TRAIN_DATA>
    The probability of documents in catagory True in all documents.
    Number of documents in catagory True / number of all documents
    '''
    # read the vocabulary
    vocab = pd.read_csv(VOCAB, index_col = 0)
    # read the trained_datas
    train_data_1 = np.loadtxt(TRAIN_DATA_1)
    train_data_0 = np.loadtxt(TRAIN_DATA_0)
    train_data_all = np.loadtxt(TRAIN_DATA_ALL)
    prob_ctg_1 = pd.read_csv(PROB_1_TRAIN_DATA, index_col = 0)
    prob_ctg_1_train_data = prob_ctg_1.loc[0, 'prob_ctg_1_train_set']
    
    
    # Delete useless cols
    col_deleted_bom = delete_col(bom)
    
    # Series
    # Parse the bom, make each col getting together to be 1 col
    new_bom = turn_series(col_deleted_bom)
    
    # nltk_convert
    stemmed_bom = new_bom.apply(stemmered_nltk_convert)
    
    # Convert the stemmed series into df
    # 1 token get 1 cell
    word_col_df = pd.DataFrame.from_records(stemmed_bom.tolist())
    
    # Sparse Matrix
    # Create a sparse Matrix for the data we want to predict
    # The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.
    sparse_predict_df = make_sparse_matrix(word_col_df, vocab)
    # Grouped by MATERIAL_ID
    sparse_predict_df_grouped = sparse_predict_df.groupby(['MATERIAL_ID', 'WORD_ID']).sum()
    # Reset it index
    sparse_predict_df_grouped = sparse_predict_df_grouped.reset_index()
    # Convert it into numpy array.
    sparse_predict_data = sparse_predict_df_grouped.to_numpy()
    
    #Full Matrix
    predict_full_feature = make_full_feature(sparse_predict_data, vocab.shape[0])
    
    #Joint probability in log format
    joint_log_ctg_1 = predict_full_feature.dot(np.log(train_data_1) - np.log(train_data_all)) + np.log(prob_ctg_1_train_data)
    joint_log_ctg_0 = predict_full_feature.dot(np.log(train_data_0)-np.log(train_data_all))+np.log(1 - prob_ctg_1_train_data)
    # Prediction
    prediction_log = joint_log_ctg_1 > joint_log_ctg_0
    
    # Get the index of the row that predicted as material in the bom
    row_list = prediction_log[prediction_log == True].index
    
    #2020/03/11
    # The difference with the func "M-List_generator" is that the func only return a list of index classified as True.
    # Later I may optimize the func "M-List_generator" same as this func, so the two func can use same code as this func.
    # Let the different part be done outside the func.
#     # Get the material from the original bom by the index in row_list
#     material_list = bom.loc[row_list,:]
    
    return row_list

# %%
x = pd.read_csv('DataSource/M-List/AB18MJ1_032_ BOM_032 BOM_material_list.csv', encoding = 'ISO-8859-1')

# %%
my_list = material_classifor(x)

# %%
my_list
# Out:
# Int64Index([32, 33, 34, 35, 36, 38], dtype='int64', name='MATERIAL_ID')

# %%
x
# Out:
#     MATERIAL_ID    0                                                  1  \
# 0             3  NaN                                                NaN
# 1            10  NaN                                                NaN
# 2            11    A                                       Shell Fabric
# 3            12    B                                       Shell Fabric
# 4            13    C                                       Shell Fabric
# 5            14    D                                             Lining
# 6            15    E                                             Other
# 7            16    F                                              Other
# 8            17    G                                              Other
# 9            18    H                                              Other
# 10           19    I                                              Other
# 11           20    J                                              Other
# 12           21    K                                              Other
# 13           22    L                                             Pellon
# 14           23    M                                             Pellon
# 15           25    L                                                NaN
# 16           26   AA                                             Zipper
# 17           27   BB                                             Zipper
# 18           28   CC                                             Zipper
# 19           29   DD                                             Zipper
# 20           30   EE                                        Zipper Pull
# 21           33   FF                                           Stoppers
# 22           34   GG                                           Stoppers
# 23           35   HH                                         Hand Pulls
# 24           36   II                                            Webbing
# 25           37   JJ                                            Webbing
# 26           38   KK                                           Hardware
# 27           39   LL                                           Hardware
# 28           40   MM                                           Hardware
# 29           41   NN                                           Drawcord
# 30           42   OO                                   Elastic Drawcord
# 31           43   PP                                           Key Clip
# 32           44   QQ                                         Main Label
# 33           45   RR                                         Size Label
# 34           46   SS                                          W/C Label
# 35           47   TT                               ABWVLP_01 Woven loop
# 36           48   UU                                        Flag  Label
# 37           49   VV                                           Branding
# 38           50   WW                                           Branding
# 39           53   XX                                            HANGTAG
# 40           54   YY                                            HANGTAG
# 41           55   ZZ                          polybag w/ warning matter
# 42           56  AAA  Country of Origin sticker (supplied by your side)
# 43           57  BBB                UPC sticker (supplied by your side)
# 44           62    3                                  ZIPPER DIRECTION:
# 45           64    5                                          HEAT CUT:
#
#                                                     2  \
# 0                                         Insulation:
# 1                                                 NaN
# 2   SOTD109-C1-Y 100% Polyester 10K/8K 10K/8K +2-L...
# 3   SOTD109-PR01-Y 100% Polyester 10K/8K 10K/8K +2...
# 4   SOTP069-C1-H 100% Polyester 10K/8K 15k/10k+2-L...
# 5   210T-E EMB07 Tery Emboss  Taffeta(Supplied by ...
# 6      Velvety Tricot - SOTO048-1 (supplied by Solis)
# 7      100% poly MESH - SOTC025-1 (supplied by Solis)
# 8   nylon/elastic lycra - SONO029-1 (supplied by S...
# 9           1x1 rib knit,good quality Arcylic/Spandex
# 10                                 Lycra binding tape
# 11                                    Gripper elastic
# 12                                   100gm Insulation
# 13                lightweight interfacing (item# TBD)
# 14                heavyweight interfacing (item# TBD)
# 15                                                NaN
# 16  YKK No.8 Vislon 2 way  zipper.  Auto-lock slid...
# 17  YKK  No.5 nylon coil zippers.  Auto-lock slide...
# 18  YKK  No.5 nylon coil zippers,1-way hidden chai...
# 19  YKK  No.5 nylon coil zippers hidden chain ,aut...
# 20  ABZP_01 Utility cord zipper pullers with tied ...
# 21                      Round Barrel stopper - K-018
# 22                              K343-2N push stoppers
# 23                           Plastic hand pulls ZP11
# 24                             Flat Webbing Tape, 8mm
# 25                        flat webbing tape 8mm width
# 26                metal eyelets, 12mm (incl. washers)
# 27  Snap Buttons ABSNP_01 (sets), 17mm (incl. wash...
# 28                     Male snap only (incl. washers)
# 29  Flat Shoelace drawcord WITH Black Oxidize fini...
# 30                                2.5 mm elastic cord
# 31         plastic key clip attched with webbing loop
# 32                         ABWV_67 Freedom Main Label
# 33                        ABWV_69V Vietnam Size Label
# 34                             Satin Label with print
# 35                        ABWVLP_01 (Supplied by SML)
# 36                ABLT_01 Flag Label (Pill logo side)
# 37                        ABPR_10 Large Airpill Print
# 38                       ABWV_103 Awesome Woven Label
# 39                                                TBD
# 40                                                TBD
# 41                         Airpill Logo Print:  16 cm
# 42                              Made in China sticker
# 43                               Sticker width 3.5 cm
# 44  CF has right hand slider, pocket zippers close...
# 45                          Elastic, webbing, taffeta
#
#                                                     3                  4  \
# 0                      100gm in the body hood sleeves                NaN
# 1                                                 NaN  FABRICS & LININGS
# 2                                           Main body                NaN
# 3                                           Main body                NaN
# 4                                       Sleeves, hood                NaN
# 5             Inside lining, powder skirt, pocket bag                NaN
# 6    Comfort chin guard, inner front pocket bag panel                NaN
# 7                       vents, internal goggle pocket                NaN
# 8                                        powder skirt                NaN
# 9                                               Cuffs                NaN
# 10                       Internal mesh pocket opening                NaN
# 11                                       powder skirt                NaN
# 12                           Main body, hood, sleeves                NaN
# 13       Inner storm flap, powder skirt closure flaps                NaN
# 14                                          hood brim                NaN
# 15                                                NaN            ZIPPERS
# 16                                               C.F.                  1
# 17                                  ( 2) hand pockets                  2
# 18                                              vents                  2
# 19              1 internal pocket at w.'s inside LEFT                  1
# 20  (2) pockets, (1) C.F. (2) vents,  (1) inside p...                  6
# 21                                           (2) hood                  2
# 22                                     (2) bottom hem                  2
# 23                                     (2) bottom hem                  2
# 24   key clip attachment at inside wearer's right ...                  1
# 25         (2)Stopper attachments loops at bottom hem                  2
# 26        (4) at hood opening,  (4) inside bottom hem                  8
# 27   (1) snap tabs at inside bottom hem,  (2) at p...                  3
# 28                                   (2) powder skirt                  2
# 29                                       Hood Opening                  1
# 30                              bottom hem adjustment                  1
# 31                       Inside wearers right pocket.                  1
# 32            inside c.b. neck, see Q/A for placement                  1
# 33              sewn in and centered below main label                  1
# 34  wearer's left side seam, 10 cm up from bottom ...                  1
# 35                       inside center back neck seam                  1
# 36                 RIGHT vent 2cm from bottom of vent                  1
# 37  Centered on wearer's back, see artwork palceme...                  1
# 38           LEFT chest, see art placement for detail                  1
# 39                                                TBD                  1
# 40                                                TBD                  1
# 41                               centered on poly bag                  1
# 42                         Centered above UPC sticker                  1
# 43                        Lookers right bottom corner                  1
# 44                                                NaN                NaN
# 45                                                NaN                NaN
#
#                       5                  6                   7  \
# 0   Collection: Freedom                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2         VINTAGE BLACK                NaN               BLACK
# 3                   NaN          DINOFLAGE                 NaN
# 4                 BLACK              BLACK             OXBLOOD
# 5                 BLACK              BLACK               BLACK
# 6                 BLACK              BLACK               BLACK
# 7                 BLACK              BLACK               BLACK
# 8                 BLACK              BLACK               BLACK
# 9                 BLACK              BLACK               BLACK
# 10                BLACK              BLACK               BLACK
# 11                BLACK              BLACK               BLACK
# 12                  NaN                NaN                 NaN
# 13                WHITE              WHITE               WHITE
# 14                WHITE              WHITE               WHITE
# 15                  NaN                NaN                 NaN
# 16                BLACK              BLACK         OXBLOOD 097
# 17                BLACK              BLACK         OXBLOOD 097
# 18                BLACK              BLACK         OXBLOOD 097
# 19                BLACK              BLACK         OXBLOOD 097
# 20                BLACK              BLACK               BLACK
# 21                BLACK         DARK OLIVE               BLACK
# 22                BLACK         DARK OLIVE               BLACK
# 23                BLACK         DARK OLIVE               BLACK
# 24                BLACK              BLACK               BLACK
# 25                BLACK              BLACK               BLACK
# 26    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 27    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 28    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 29                BLACK         DARK OLIVE               BLACK
# 30                BLACK         DARK OLIVE               BLACK
# 31                BLACK              BLACK               BLACK
# 32           GOLD/BLACK         GOLD/BLACK          GOLD/BLACK
# 33           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 34                BLACK              BLACK               BLACK
# 35           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 36          BLACK/WHITE        BLACK/WHITE         BLACK/WHITE
# 37                BLACK              BLACK  OXBLOOD 19-1331TPX
# 38           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 39                  TBD                TBD                 TBD
# 40                  TBD                TBD                 TBD
# 41                CLEAR              CLEAR               CLEAR
# 42                  TBD                TBD                 TBD
# 43                  TBD                TBD                 TBD
# 44                  NaN                NaN                 NaN
# 45                  NaN                NaN                 NaN
#
#                     8            9
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2           DARK NAVY  AB18MJ1_032
# 3                 NaN  AB18MJ1_032
# 4               CAMEL  AB18MJ1_032
# 5               BLACK  AB18MJ1_032
# 6               BLACK  AB18MJ1_032
# 7               BLACK  AB18MJ1_032
# 8               BLACK  AB18MJ1_032
# 9               BLACK  AB18MJ1_032
# 10              BLACK  AB18MJ1_032
# 11              BLACK  AB18MJ1_032
# 12                NaN  AB18MJ1_032
# 13              WHITE  AB18MJ1_032
# 14              WHITE  AB18MJ1_032
# 15                NaN  AB18MJ1_032
# 16          CAMEL 161  AB18MJ1_032
# 17          CAMEL 161  AB18MJ1_032
# 18          CAMEL 161  AB18MJ1_032
# 19          CAMEL 161  AB18MJ1_032
# 20              BLACK  AB18MJ1_032
# 21              BLACK  AB18MJ1_032
# 22              BLACK  AB18MJ1_032
# 23              BLACK  AB18MJ1_032
# 24              BLACK  AB18MJ1_032
# 25              BLACK  AB18MJ1_032
# 26  MATTE BLACK BI-48  AB18MJ1_032
# 27  MATTE BLACK BI-48  AB18MJ1_032
# 28  MATTE BLACK BI-48  AB18MJ1_032
# 29              BLACK  AB18MJ1_032
# 30              BLACK  AB18MJ1_032
# 31              BLACK  AB18MJ1_032
# 32         GOLD/BLACK  AB18MJ1_032
# 33         BLACK/GOLD  AB18MJ1_032
# 34              BLACK  AB18MJ1_032
# 35         BLACK/GOLD  AB18MJ1_032
# 36        BLACK/WHITE  AB18MJ1_032
# 37   CAMEL 17-1019TPX  AB18MJ1_032
# 38         BLACK/GOLD  AB18MJ1_032
# 39                TBD  AB18MJ1_032
# 40                TBD  AB18MJ1_032
# 41              CLEAR  AB18MJ1_032
# 42                TBD  AB18MJ1_032
# 43                TBD  AB18MJ1_032
# 44                NaN          NaN
# 45                NaN          NaN

# %%
p = [0,2,3]

# %%
type(p)
# Out:
# list

# %%
x.loc[lambda x: p]['MATERIAL_ID']
# Out:
# 0     3
# 2    11
# 3    12
# Name: MATERIAL_ID, dtype: int64

# %%
x
# Out:
#     MATERIAL_ID    0                                                  1  \
# 0             3  NaN                                                NaN
# 1            10  NaN                                                NaN
# 2            11    A                                       Shell Fabric
# 3            12    B                                       Shell Fabric
# 4            13    C                                       Shell Fabric
# 5            14    D                                             Lining
# 6            15    E                                             Other
# 7            16    F                                              Other
# 8            17    G                                              Other
# 9            18    H                                              Other
# 10           19    I                                              Other
# 11           20    J                                              Other
# 12           21    K                                              Other
# 13           22    L                                             Pellon
# 14           23    M                                             Pellon
# 15           25    L                                                NaN
# 16           26   AA                                             Zipper
# 17           27   BB                                             Zipper
# 18           28   CC                                             Zipper
# 19           29   DD                                             Zipper
# 20           30   EE                                        Zipper Pull
# 21           33   FF                                           Stoppers
# 22           34   GG                                           Stoppers
# 23           35   HH                                         Hand Pulls
# 24           36   II                                            Webbing
# 25           37   JJ                                            Webbing
# 26           38   KK                                           Hardware
# 27           39   LL                                           Hardware
# 28           40   MM                                           Hardware
# 29           41   NN                                           Drawcord
# 30           42   OO                                   Elastic Drawcord
# 31           43   PP                                           Key Clip
# 32           44   QQ                                         Main Label
# 33           45   RR                                         Size Label
# 34           46   SS                                          W/C Label
# 35           47   TT                               ABWVLP_01 Woven loop
# 36           48   UU                                        Flag  Label
# 37           49   VV                                           Branding
# 38           50   WW                                           Branding
# 39           53   XX                                            HANGTAG
# 40           54   YY                                            HANGTAG
# 41           55   ZZ                          polybag w/ warning matter
# 42           56  AAA  Country of Origin sticker (supplied by your side)
# 43           57  BBB                UPC sticker (supplied by your side)
# 44           62    3                                  ZIPPER DIRECTION:
# 45           64    5                                          HEAT CUT:
#
#                                                     2  \
# 0                                         Insulation:
# 1                                                 NaN
# 2   SOTD109-C1-Y 100% Polyester 10K/8K 10K/8K +2-L...
# 3   SOTD109-PR01-Y 100% Polyester 10K/8K 10K/8K +2...
# 4   SOTP069-C1-H 100% Polyester 10K/8K 15k/10k+2-L...
# 5   210T-E EMB07 Tery Emboss  Taffeta(Supplied by ...
# 6      Velvety Tricot - SOTO048-1 (supplied by Solis)
# 7      100% poly MESH - SOTC025-1 (supplied by Solis)
# 8   nylon/elastic lycra - SONO029-1 (supplied by S...
# 9           1x1 rib knit,good quality Arcylic/Spandex
# 10                                 Lycra binding tape
# 11                                    Gripper elastic
# 12                                   100gm Insulation
# 13                lightweight interfacing (item# TBD)
# 14                heavyweight interfacing (item# TBD)
# 15                                                NaN
# 16  YKK No.8 Vislon 2 way  zipper.  Auto-lock slid...
# 17  YKK  No.5 nylon coil zippers.  Auto-lock slide...
# 18  YKK  No.5 nylon coil zippers,1-way hidden chai...
# 19  YKK  No.5 nylon coil zippers hidden chain ,aut...
# 20  ABZP_01 Utility cord zipper pullers with tied ...
# 21                      Round Barrel stopper - K-018
# 22                              K343-2N push stoppers
# 23                           Plastic hand pulls ZP11
# 24                             Flat Webbing Tape, 8mm
# 25                        flat webbing tape 8mm width
# 26                metal eyelets, 12mm (incl. washers)
# 27  Snap Buttons ABSNP_01 (sets), 17mm (incl. wash...
# 28                     Male snap only (incl. washers)
# 29  Flat Shoelace drawcord WITH Black Oxidize fini...
# 30                                2.5 mm elastic cord
# 31         plastic key clip attched with webbing loop
# 32                         ABWV_67 Freedom Main Label
# 33                        ABWV_69V Vietnam Size Label
# 34                             Satin Label with print
# 35                        ABWVLP_01 (Supplied by SML)
# 36                ABLT_01 Flag Label (Pill logo side)
# 37                        ABPR_10 Large Airpill Print
# 38                       ABWV_103 Awesome Woven Label
# 39                                                TBD
# 40                                                TBD
# 41                         Airpill Logo Print:  16 cm
# 42                              Made in China sticker
# 43                               Sticker width 3.5 cm
# 44  CF has right hand slider, pocket zippers close...
# 45                          Elastic, webbing, taffeta
#
#                                                     3                  4  \
# 0                      100gm in the body hood sleeves                NaN
# 1                                                 NaN  FABRICS & LININGS
# 2                                           Main body                NaN
# 3                                           Main body                NaN
# 4                                       Sleeves, hood                NaN
# 5             Inside lining, powder skirt, pocket bag                NaN
# 6    Comfort chin guard, inner front pocket bag panel                NaN
# 7                       vents, internal goggle pocket                NaN
# 8                                        powder skirt                NaN
# 9                                               Cuffs                NaN
# 10                       Internal mesh pocket opening                NaN
# 11                                       powder skirt                NaN
# 12                           Main body, hood, sleeves                NaN
# 13       Inner storm flap, powder skirt closure flaps                NaN
# 14                                          hood brim                NaN
# 15                                                NaN            ZIPPERS
# 16                                               C.F.                  1
# 17                                  ( 2) hand pockets                  2
# 18                                              vents                  2
# 19              1 internal pocket at w.'s inside LEFT                  1
# 20  (2) pockets, (1) C.F. (2) vents,  (1) inside p...                  6
# 21                                           (2) hood                  2
# 22                                     (2) bottom hem                  2
# 23                                     (2) bottom hem                  2
# 24   key clip attachment at inside wearer's right ...                  1
# 25         (2)Stopper attachments loops at bottom hem                  2
# 26        (4) at hood opening,  (4) inside bottom hem                  8
# 27   (1) snap tabs at inside bottom hem,  (2) at p...                  3
# 28                                   (2) powder skirt                  2
# 29                                       Hood Opening                  1
# 30                              bottom hem adjustment                  1
# 31                       Inside wearers right pocket.                  1
# 32            inside c.b. neck, see Q/A for placement                  1
# 33              sewn in and centered below main label                  1
# 34  wearer's left side seam, 10 cm up from bottom ...                  1
# 35                       inside center back neck seam                  1
# 36                 RIGHT vent 2cm from bottom of vent                  1
# 37  Centered on wearer's back, see artwork palceme...                  1
# 38           LEFT chest, see art placement for detail                  1
# 39                                                TBD                  1
# 40                                                TBD                  1
# 41                               centered on poly bag                  1
# 42                         Centered above UPC sticker                  1
# 43                        Lookers right bottom corner                  1
# 44                                                NaN                NaN
# 45                                                NaN                NaN
#
#                       5                  6                   7  \
# 0   Collection: Freedom                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2         VINTAGE BLACK                NaN               BLACK
# 3                   NaN          DINOFLAGE                 NaN
# 4                 BLACK              BLACK             OXBLOOD
# 5                 BLACK              BLACK               BLACK
# 6                 BLACK              BLACK               BLACK
# 7                 BLACK              BLACK               BLACK
# 8                 BLACK              BLACK               BLACK
# 9                 BLACK              BLACK               BLACK
# 10                BLACK              BLACK               BLACK
# 11                BLACK              BLACK               BLACK
# 12                  NaN                NaN                 NaN
# 13                WHITE              WHITE               WHITE
# 14                WHITE              WHITE               WHITE
# 15                  NaN                NaN                 NaN
# 16                BLACK              BLACK         OXBLOOD 097
# 17                BLACK              BLACK         OXBLOOD 097
# 18                BLACK              BLACK         OXBLOOD 097
# 19                BLACK              BLACK         OXBLOOD 097
# 20                BLACK              BLACK               BLACK
# 21                BLACK         DARK OLIVE               BLACK
# 22                BLACK         DARK OLIVE               BLACK
# 23                BLACK         DARK OLIVE               BLACK
# 24                BLACK              BLACK               BLACK
# 25                BLACK              BLACK               BLACK
# 26    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 27    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 28    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 29                BLACK         DARK OLIVE               BLACK
# 30                BLACK         DARK OLIVE               BLACK
# 31                BLACK              BLACK               BLACK
# 32           GOLD/BLACK         GOLD/BLACK          GOLD/BLACK
# 33           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 34                BLACK              BLACK               BLACK
# 35           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 36          BLACK/WHITE        BLACK/WHITE         BLACK/WHITE
# 37                BLACK              BLACK  OXBLOOD 19-1331TPX
# 38           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 39                  TBD                TBD                 TBD
# 40                  TBD                TBD                 TBD
# 41                CLEAR              CLEAR               CLEAR
# 42                  TBD                TBD                 TBD
# 43                  TBD                TBD                 TBD
# 44                  NaN                NaN                 NaN
# 45                  NaN                NaN                 NaN
#
#                     8            9
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2           DARK NAVY  AB18MJ1_032
# 3                 NaN  AB18MJ1_032
# 4               CAMEL  AB18MJ1_032
# 5               BLACK  AB18MJ1_032
# 6               BLACK  AB18MJ1_032
# 7               BLACK  AB18MJ1_032
# 8               BLACK  AB18MJ1_032
# 9               BLACK  AB18MJ1_032
# 10              BLACK  AB18MJ1_032
# 11              BLACK  AB18MJ1_032
# 12                NaN  AB18MJ1_032
# 13              WHITE  AB18MJ1_032
# 14              WHITE  AB18MJ1_032
# 15                NaN  AB18MJ1_032
# 16          CAMEL 161  AB18MJ1_032
# 17          CAMEL 161  AB18MJ1_032
# 18          CAMEL 161  AB18MJ1_032
# 19          CAMEL 161  AB18MJ1_032
# 20              BLACK  AB18MJ1_032
# 21              BLACK  AB18MJ1_032
# 22              BLACK  AB18MJ1_032
# 23              BLACK  AB18MJ1_032
# 24              BLACK  AB18MJ1_032
# 25              BLACK  AB18MJ1_032
# 26  MATTE BLACK BI-48  AB18MJ1_032
# 27  MATTE BLACK BI-48  AB18MJ1_032
# 28  MATTE BLACK BI-48  AB18MJ1_032
# 29              BLACK  AB18MJ1_032
# 30              BLACK  AB18MJ1_032
# 31              BLACK  AB18MJ1_032
# 32         GOLD/BLACK  AB18MJ1_032
# 33         BLACK/GOLD  AB18MJ1_032
# 34              BLACK  AB18MJ1_032
# 35         BLACK/GOLD  AB18MJ1_032
# 36        BLACK/WHITE  AB18MJ1_032
# 37   CAMEL 17-1019TPX  AB18MJ1_032
# 38         BLACK/GOLD  AB18MJ1_032
# 39                TBD  AB18MJ1_032
# 40                TBD  AB18MJ1_032
# 41              CLEAR  AB18MJ1_032
# 42                TBD  AB18MJ1_032
# 43                TBD  AB18MJ1_032
# 44                NaN          NaN
# 45                NaN          NaN

# %%
x.at[[0,1], 'CATEGORY'] = "Steve"

# %%
x
# Out:
#     MATERIAL_ID    0                                                  1  \
# 0             3  NaN                                                NaN
# 1            10  NaN                                                NaN
# 2            11    A                                       Shell Fabric
# 3            12    B                                       Shell Fabric
# 4            13    C                                       Shell Fabric
# 5            14    D                                             Lining
# 6            15    E                                             Other
# 7            16    F                                              Other
# 8            17    G                                              Other
# 9            18    H                                              Other
# 10           19    I                                              Other
# 11           20    J                                              Other
# 12           21    K                                              Other
# 13           22    L                                             Pellon
# 14           23    M                                             Pellon
# 15           25    L                                                NaN
# 16           26   AA                                             Zipper
# 17           27   BB                                             Zipper
# 18           28   CC                                             Zipper
# 19           29   DD                                             Zipper
# 20           30   EE                                        Zipper Pull
# 21           33   FF                                           Stoppers
# 22           34   GG                                           Stoppers
# 23           35   HH                                         Hand Pulls
# 24           36   II                                            Webbing
# 25           37   JJ                                            Webbing
# 26           38   KK                                           Hardware
# 27           39   LL                                           Hardware
# 28           40   MM                                           Hardware
# 29           41   NN                                           Drawcord
# 30           42   OO                                   Elastic Drawcord
# 31           43   PP                                           Key Clip
# 32           44   QQ                                         Main Label
# 33           45   RR                                         Size Label
# 34           46   SS                                          W/C Label
# 35           47   TT                               ABWVLP_01 Woven loop
# 36           48   UU                                        Flag  Label
# 37           49   VV                                           Branding
# 38           50   WW                                           Branding
# 39           53   XX                                            HANGTAG
# 40           54   YY                                            HANGTAG
# 41           55   ZZ                          polybag w/ warning matter
# 42           56  AAA  Country of Origin sticker (supplied by your side)
# 43           57  BBB                UPC sticker (supplied by your side)
# 44           62    3                                  ZIPPER DIRECTION:
# 45           64    5                                          HEAT CUT:
#
#                                                     2  \
# 0                                         Insulation:
# 1                                                 NaN
# 2   SOTD109-C1-Y 100% Polyester 10K/8K 10K/8K +2-L...
# 3   SOTD109-PR01-Y 100% Polyester 10K/8K 10K/8K +2...
# 4   SOTP069-C1-H 100% Polyester 10K/8K 15k/10k+2-L...
# 5   210T-E EMB07 Tery Emboss  Taffeta(Supplied by ...
# 6      Velvety Tricot - SOTO048-1 (supplied by Solis)
# 7      100% poly MESH - SOTC025-1 (supplied by Solis)
# 8   nylon/elastic lycra - SONO029-1 (supplied by S...
# 9           1x1 rib knit,good quality Arcylic/Spandex
# 10                                 Lycra binding tape
# 11                                    Gripper elastic
# 12                                   100gm Insulation
# 13                lightweight interfacing (item# TBD)
# 14                heavyweight interfacing (item# TBD)
# 15                                                NaN
# 16  YKK No.8 Vislon 2 way  zipper.  Auto-lock slid...
# 17  YKK  No.5 nylon coil zippers.  Auto-lock slide...
# 18  YKK  No.5 nylon coil zippers,1-way hidden chai...
# 19  YKK  No.5 nylon coil zippers hidden chain ,aut...
# 20  ABZP_01 Utility cord zipper pullers with tied ...
# 21                      Round Barrel stopper - K-018
# 22                              K343-2N push stoppers
# 23                           Plastic hand pulls ZP11
# 24                             Flat Webbing Tape, 8mm
# 25                        flat webbing tape 8mm width
# 26                metal eyelets, 12mm (incl. washers)
# 27  Snap Buttons ABSNP_01 (sets), 17mm (incl. wash...
# 28                     Male snap only (incl. washers)
# 29  Flat Shoelace drawcord WITH Black Oxidize fini...
# 30                                2.5 mm elastic cord
# 31         plastic key clip attched with webbing loop
# 32                         ABWV_67 Freedom Main Label
# 33                        ABWV_69V Vietnam Size Label
# 34                             Satin Label with print
# 35                        ABWVLP_01 (Supplied by SML)
# 36                ABLT_01 Flag Label (Pill logo side)
# 37                        ABPR_10 Large Airpill Print
# 38                       ABWV_103 Awesome Woven Label
# 39                                                TBD
# 40                                                TBD
# 41                         Airpill Logo Print:  16 cm
# 42                              Made in China sticker
# 43                               Sticker width 3.5 cm
# 44  CF has right hand slider, pocket zippers close...
# 45                          Elastic, webbing, taffeta
#
#                                                     3                  4  \
# 0                      100gm in the body hood sleeves                NaN
# 1                                                 NaN  FABRICS & LININGS
# 2                                           Main body                NaN
# 3                                           Main body                NaN
# 4                                       Sleeves, hood                NaN
# 5             Inside lining, powder skirt, pocket bag                NaN
# 6    Comfort chin guard, inner front pocket bag panel                NaN
# 7                       vents, internal goggle pocket                NaN
# 8                                        powder skirt                NaN
# 9                                               Cuffs                NaN
# 10                       Internal mesh pocket opening                NaN
# 11                                       powder skirt                NaN
# 12                           Main body, hood, sleeves                NaN
# 13       Inner storm flap, powder skirt closure flaps                NaN
# 14                                          hood brim                NaN
# 15                                                NaN            ZIPPERS
# 16                                               C.F.                  1
# 17                                  ( 2) hand pockets                  2
# 18                                              vents                  2
# 19              1 internal pocket at w.'s inside LEFT                  1
# 20  (2) pockets, (1) C.F. (2) vents,  (1) inside p...                  6
# 21                                           (2) hood                  2
# 22                                     (2) bottom hem                  2
# 23                                     (2) bottom hem                  2
# 24   key clip attachment at inside wearer's right ...                  1
# 25         (2)Stopper attachments loops at bottom hem                  2
# 26        (4) at hood opening,  (4) inside bottom hem                  8
# 27   (1) snap tabs at inside bottom hem,  (2) at p...                  3
# 28                                   (2) powder skirt                  2
# 29                                       Hood Opening                  1
# 30                              bottom hem adjustment                  1
# 31                       Inside wearers right pocket.                  1
# 32            inside c.b. neck, see Q/A for placement                  1
# 33              sewn in and centered below main label                  1
# 34  wearer's left side seam, 10 cm up from bottom ...                  1
# 35                       inside center back neck seam                  1
# 36                 RIGHT vent 2cm from bottom of vent                  1
# 37  Centered on wearer's back, see artwork palceme...                  1
# 38           LEFT chest, see art placement for detail                  1
# 39                                                TBD                  1
# 40                                                TBD                  1
# 41                               centered on poly bag                  1
# 42                         Centered above UPC sticker                  1
# 43                        Lookers right bottom corner                  1
# 44                                                NaN                NaN
# 45                                                NaN                NaN
#
#                       5                  6                   7  \
# 0   Collection: Freedom                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2         VINTAGE BLACK                NaN               BLACK
# 3                   NaN          DINOFLAGE                 NaN
# 4                 BLACK              BLACK             OXBLOOD
# 5                 BLACK              BLACK               BLACK
# 6                 BLACK              BLACK               BLACK
# 7                 BLACK              BLACK               BLACK
# 8                 BLACK              BLACK               BLACK
# 9                 BLACK              BLACK               BLACK
# 10                BLACK              BLACK               BLACK
# 11                BLACK              BLACK               BLACK
# 12                  NaN                NaN                 NaN
# 13                WHITE              WHITE               WHITE
# 14                WHITE              WHITE               WHITE
# 15                  NaN                NaN                 NaN
# 16                BLACK              BLACK         OXBLOOD 097
# 17                BLACK              BLACK         OXBLOOD 097
# 18                BLACK              BLACK         OXBLOOD 097
# 19                BLACK              BLACK         OXBLOOD 097
# 20                BLACK              BLACK               BLACK
# 21                BLACK         DARK OLIVE               BLACK
# 22                BLACK         DARK OLIVE               BLACK
# 23                BLACK         DARK OLIVE               BLACK
# 24                BLACK              BLACK               BLACK
# 25                BLACK              BLACK               BLACK
# 26    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 27    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 28    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 29                BLACK         DARK OLIVE               BLACK
# 30                BLACK         DARK OLIVE               BLACK
# 31                BLACK              BLACK               BLACK
# 32           GOLD/BLACK         GOLD/BLACK          GOLD/BLACK
# 33           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 34                BLACK              BLACK               BLACK
# 35           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 36          BLACK/WHITE        BLACK/WHITE         BLACK/WHITE
# 37                BLACK              BLACK  OXBLOOD 19-1331TPX
# 38           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 39                  TBD                TBD                 TBD
# 40                  TBD                TBD                 TBD
# 41                CLEAR              CLEAR               CLEAR
# 42                  TBD                TBD                 TBD
# 43                  TBD                TBD                 TBD
# 44                  NaN                NaN                 NaN
# 45                  NaN                NaN                 NaN
#
#                     8            9 CATEGORY
# 0                 NaN          NaN    Steve
# 1                 NaN          NaN    Steve
# 2           DARK NAVY  AB18MJ1_032      NaN
# 3                 NaN  AB18MJ1_032      NaN
# 4               CAMEL  AB18MJ1_032      NaN
# 5               BLACK  AB18MJ1_032      NaN
# 6               BLACK  AB18MJ1_032      NaN
# 7               BLACK  AB18MJ1_032      NaN
# 8               BLACK  AB18MJ1_032      NaN
# 9               BLACK  AB18MJ1_032      NaN
# 10              BLACK  AB18MJ1_032      NaN
# 11              BLACK  AB18MJ1_032      NaN
# 12                NaN  AB18MJ1_032      NaN
# 13              WHITE  AB18MJ1_032      NaN
# 14              WHITE  AB18MJ1_032      NaN
# 15                NaN  AB18MJ1_032      NaN
# 16          CAMEL 161  AB18MJ1_032      NaN
# 17          CAMEL 161  AB18MJ1_032      NaN
# 18          CAMEL 161  AB18MJ1_032      NaN
# 19          CAMEL 161  AB18MJ1_032      NaN
# 20              BLACK  AB18MJ1_032      NaN
# 21              BLACK  AB18MJ1_032      NaN
# 22              BLACK  AB18MJ1_032      NaN
# 23              BLACK  AB18MJ1_032      NaN
# 24              BLACK  AB18MJ1_032      NaN
# 25              BLACK  AB18MJ1_032      NaN
# 26  MATTE BLACK BI-48  AB18MJ1_032      NaN
# 27  MATTE BLACK BI-48  AB18MJ1_032      NaN
# 28  MATTE BLACK BI-48  AB18MJ1_032      NaN
# 29              BLACK  AB18MJ1_032      NaN
# 30              BLACK  AB18MJ1_032      NaN
# 31              BLACK  AB18MJ1_032      NaN
# 32         GOLD/BLACK  AB18MJ1_032      NaN
# 33         BLACK/GOLD  AB18MJ1_032      NaN
# 34              BLACK  AB18MJ1_032      NaN
# 35         BLACK/GOLD  AB18MJ1_032      NaN
# 36        BLACK/WHITE  AB18MJ1_032      NaN
# 37   CAMEL 17-1019TPX  AB18MJ1_032      NaN
# 38         BLACK/GOLD  AB18MJ1_032      NaN
# 39                TBD  AB18MJ1_032      NaN
# 40                TBD  AB18MJ1_032      NaN
# 41              CLEAR  AB18MJ1_032      NaN
# 42                TBD  AB18MJ1_032      NaN
# 43                TBD  AB18MJ1_032      NaN
# 44                NaN          NaN      NaN
# 45                NaN          NaN      NaN

# %%
ds = pd.DataFrame({
    'A':['B','F','J'],
    'B':[4,'tt','77'],
    'C':['cc', 'cc2','cc3']
})

# %%
ds
# Out:
#    A   B    C
# 0  B   4   cc
# 1  F  tt  cc2
# 2  J  77  cc3

# %%
test_list = [0,2]

# %%
ds.at[test_list,['B']] = 'Steve'

# %%
ds
# Out:
#    A      B    C
# 0  B  Steve   cc
# 1  F     tt  cc2
# 2  J  Steve  cc3

# %% [markdown]
# # Main Funciton
# ## Loop through materials designated as category.
# * Analyze a M-List with several sets of train-data and vocabulary.
# * Each set of trainned-data and vocabulary represents 1 category of material, such as fabric, zipper, label.
# * This func will feed the func "material_classifor" each set of trainned-data and vocabulary by order.

# %%
M = 'DataSource/M-List/AB18MJ1_032_ BOM_032 BOM_material_list.csv'

# %%
def fill_out_col_category(M_list, LIST = CATEGORY_LIST,) :
    '''
    Param_1
    <M_list>
    M_list in CSV format
    The func will turn it into a DataFrame while calculating.
    
    Param_2
    An array in type List.
    '''
    bom = pd.read_csv(M_list, encoding = 'ISO-8859-1')
    bom.insert(1, 'CATEGORY', 'other', True)
    
    for cate in LIST:
        SUBJECT = cate
        ROW_LIST = material_classifor(bom)
        bom.at[ROW_LIST, 'CATEGORY'] = cate
    
    return bom

# %%
x_bom = fill_out_col_category(M)

# %%
x_bom
# Out:
#     MATERIAL_ID CATEGORY    0  \
# 0             3    other  NaN
# 1            10    other  NaN
# 2            11    other    A
# 3            12    other    B
# 4            13    other    C
# 5            14    other    D
# 6            15    other    E
# 7            16    other    F
# 8            17    other    G
# 9            18    other    H
# 10           19    other    I
# 11           20    other    J
# 12           21    other    K
# 13           22    other    L
# 14           23    other    M
# 15           25    other    L
# 16           26    other   AA
# 17           27    other   BB
# 18           28    other   CC
# 19           29    other   DD
# 20           30    other   EE
# 21           33    other   FF
# 22           34    other   GG
# 23           35    other   HH
# 24           36    other   II
# 25           37    other   JJ
# 26           38    other   KK
# 27           39    other   LL
# 28           40    other   MM
# 29           41    other   NN
# 30           42    other   OO
# 31           43    other   PP
# 32           44   fabric   QQ
# 33           45   fabric   RR
# 34           46   fabric   SS
# 35           47   fabric   TT
# 36           48   fabric   UU
# 37           49    other   VV
# 38           50   fabric   WW
# 39           53    other   XX
# 40           54    other   YY
# 41           55    other   ZZ
# 42           56    other  AAA
# 43           57    other  BBB
# 44           62    other    3
# 45           64    other    5
#
#                                                     1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                        Shell Fabric
# 3                                        Shell Fabric
# 4                                        Shell Fabric
# 5                                              Lining
# 6                                              Other
# 7                                               Other
# 8                                               Other
# 9                                               Other
# 10                                              Other
# 11                                              Other
# 12                                              Other
# 13                                             Pellon
# 14                                             Pellon
# 15                                                NaN
# 16                                             Zipper
# 17                                             Zipper
# 18                                             Zipper
# 19                                             Zipper
# 20                                        Zipper Pull
# 21                                           Stoppers
# 22                                           Stoppers
# 23                                         Hand Pulls
# 24                                            Webbing
# 25                                            Webbing
# 26                                           Hardware
# 27                                           Hardware
# 28                                           Hardware
# 29                                           Drawcord
# 30                                   Elastic Drawcord
# 31                                           Key Clip
# 32                                         Main Label
# 33                                         Size Label
# 34                                          W/C Label
# 35                               ABWVLP_01 Woven loop
# 36                                        Flag  Label
# 37                                           Branding
# 38                                           Branding
# 39                                            HANGTAG
# 40                                            HANGTAG
# 41                          polybag w/ warning matter
# 42  Country of Origin sticker (supplied by your side)
# 43                UPC sticker (supplied by your side)
# 44                                  ZIPPER DIRECTION:
# 45                                          HEAT CUT:
#
#                                                     2  \
# 0                                         Insulation:
# 1                                                 NaN
# 2   SOTD109-C1-Y 100% Polyester 10K/8K 10K/8K +2-L...
# 3   SOTD109-PR01-Y 100% Polyester 10K/8K 10K/8K +2...
# 4   SOTP069-C1-H 100% Polyester 10K/8K 15k/10k+2-L...
# 5   210T-E EMB07 Tery Emboss  Taffeta(Supplied by ...
# 6      Velvety Tricot - SOTO048-1 (supplied by Solis)
# 7      100% poly MESH - SOTC025-1 (supplied by Solis)
# 8   nylon/elastic lycra - SONO029-1 (supplied by S...
# 9           1x1 rib knit,good quality Arcylic/Spandex
# 10                                 Lycra binding tape
# 11                                    Gripper elastic
# 12                                   100gm Insulation
# 13                lightweight interfacing (item# TBD)
# 14                heavyweight interfacing (item# TBD)
# 15                                                NaN
# 16  YKK No.8 Vislon 2 way  zipper.  Auto-lock slid...
# 17  YKK  No.5 nylon coil zippers.  Auto-lock slide...
# 18  YKK  No.5 nylon coil zippers,1-way hidden chai...
# 19  YKK  No.5 nylon coil zippers hidden chain ,aut...
# 20  ABZP_01 Utility cord zipper pullers with tied ...
# 21                      Round Barrel stopper - K-018
# 22                              K343-2N push stoppers
# 23                           Plastic hand pulls ZP11
# 24                             Flat Webbing Tape, 8mm
# 25                        flat webbing tape 8mm width
# 26                metal eyelets, 12mm (incl. washers)
# 27  Snap Buttons ABSNP_01 (sets), 17mm (incl. wash...
# 28                     Male snap only (incl. washers)
# 29  Flat Shoelace drawcord WITH Black Oxidize fini...
# 30                                2.5 mm elastic cord
# 31         plastic key clip attched with webbing loop
# 32                         ABWV_67 Freedom Main Label
# 33                        ABWV_69V Vietnam Size Label
# 34                             Satin Label with print
# 35                        ABWVLP_01 (Supplied by SML)
# 36                ABLT_01 Flag Label (Pill logo side)
# 37                        ABPR_10 Large Airpill Print
# 38                       ABWV_103 Awesome Woven Label
# 39                                                TBD
# 40                                                TBD
# 41                         Airpill Logo Print:  16 cm
# 42                              Made in China sticker
# 43                               Sticker width 3.5 cm
# 44  CF has right hand slider, pocket zippers close...
# 45                          Elastic, webbing, taffeta
#
#                                                     3                  4  \
# 0                      100gm in the body hood sleeves                NaN
# 1                                                 NaN  FABRICS & LININGS
# 2                                           Main body                NaN
# 3                                           Main body                NaN
# 4                                       Sleeves, hood                NaN
# 5             Inside lining, powder skirt, pocket bag                NaN
# 6    Comfort chin guard, inner front pocket bag panel                NaN
# 7                       vents, internal goggle pocket                NaN
# 8                                        powder skirt                NaN
# 9                                               Cuffs                NaN
# 10                       Internal mesh pocket opening                NaN
# 11                                       powder skirt                NaN
# 12                           Main body, hood, sleeves                NaN
# 13       Inner storm flap, powder skirt closure flaps                NaN
# 14                                          hood brim                NaN
# 15                                                NaN            ZIPPERS
# 16                                               C.F.                  1
# 17                                  ( 2) hand pockets                  2
# 18                                              vents                  2
# 19              1 internal pocket at w.'s inside LEFT                  1
# 20  (2) pockets, (1) C.F. (2) vents,  (1) inside p...                  6
# 21                                           (2) hood                  2
# 22                                     (2) bottom hem                  2
# 23                                     (2) bottom hem                  2
# 24   key clip attachment at inside wearer's right ...                  1
# 25         (2)Stopper attachments loops at bottom hem                  2
# 26        (4) at hood opening,  (4) inside bottom hem                  8
# 27   (1) snap tabs at inside bottom hem,  (2) at p...                  3
# 28                                   (2) powder skirt                  2
# 29                                       Hood Opening                  1
# 30                              bottom hem adjustment                  1
# 31                       Inside wearers right pocket.                  1
# 32            inside c.b. neck, see Q/A for placement                  1
# 33              sewn in and centered below main label                  1
# 34  wearer's left side seam, 10 cm up from bottom ...                  1
# 35                       inside center back neck seam                  1
# 36                 RIGHT vent 2cm from bottom of vent                  1
# 37  Centered on wearer's back, see artwork palceme...                  1
# 38           LEFT chest, see art placement for detail                  1
# 39                                                TBD                  1
# 40                                                TBD                  1
# 41                               centered on poly bag                  1
# 42                         Centered above UPC sticker                  1
# 43                        Lookers right bottom corner                  1
# 44                                                NaN                NaN
# 45                                                NaN                NaN
#
#                       5                  6                   7  \
# 0   Collection: Freedom                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2         VINTAGE BLACK                NaN               BLACK
# 3                   NaN          DINOFLAGE                 NaN
# 4                 BLACK              BLACK             OXBLOOD
# 5                 BLACK              BLACK               BLACK
# 6                 BLACK              BLACK               BLACK
# 7                 BLACK              BLACK               BLACK
# 8                 BLACK              BLACK               BLACK
# 9                 BLACK              BLACK               BLACK
# 10                BLACK              BLACK               BLACK
# 11                BLACK              BLACK               BLACK
# 12                  NaN                NaN                 NaN
# 13                WHITE              WHITE               WHITE
# 14                WHITE              WHITE               WHITE
# 15                  NaN                NaN                 NaN
# 16                BLACK              BLACK         OXBLOOD 097
# 17                BLACK              BLACK         OXBLOOD 097
# 18                BLACK              BLACK         OXBLOOD 097
# 19                BLACK              BLACK         OXBLOOD 097
# 20                BLACK              BLACK               BLACK
# 21                BLACK         DARK OLIVE               BLACK
# 22                BLACK         DARK OLIVE               BLACK
# 23                BLACK         DARK OLIVE               BLACK
# 24                BLACK              BLACK               BLACK
# 25                BLACK              BLACK               BLACK
# 26    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 27    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 28    MATTE BLACK BI-48  MATTE BLACK BI-48   MATTE BLACK BI-48
# 29                BLACK         DARK OLIVE               BLACK
# 30                BLACK         DARK OLIVE               BLACK
# 31                BLACK              BLACK               BLACK
# 32           GOLD/BLACK         GOLD/BLACK          GOLD/BLACK
# 33           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 34                BLACK              BLACK               BLACK
# 35           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 36          BLACK/WHITE        BLACK/WHITE         BLACK/WHITE
# 37                BLACK              BLACK  OXBLOOD 19-1331TPX
# 38           BLACK/GOLD         BLACK/GOLD          BLACK/GOLD
# 39                  TBD                TBD                 TBD
# 40                  TBD                TBD                 TBD
# 41                CLEAR              CLEAR               CLEAR
# 42                  TBD                TBD                 TBD
# 43                  TBD                TBD                 TBD
# 44                  NaN                NaN                 NaN
# 45                  NaN                NaN                 NaN
#
#                     8            9
# 0                 NaN          NaN
# 1                 NaN          NaN
# 2           DARK NAVY  AB18MJ1_032
# 3                 NaN  AB18MJ1_032
# 4               CAMEL  AB18MJ1_032
# 5               BLACK  AB18MJ1_032
# 6               BLACK  AB18MJ1_032
# 7               BLACK  AB18MJ1_032
# 8               BLACK  AB18MJ1_032
# 9               BLACK  AB18MJ1_032
# 10              BLACK  AB18MJ1_032
# 11              BLACK  AB18MJ1_032
# 12                NaN  AB18MJ1_032
# 13              WHITE  AB18MJ1_032
# 14              WHITE  AB18MJ1_032
# 15                NaN  AB18MJ1_032
# 16          CAMEL 161  AB18MJ1_032
# 17          CAMEL 161  AB18MJ1_032
# 18          CAMEL 161  AB18MJ1_032
# 19          CAMEL 161  AB18MJ1_032
# 20              BLACK  AB18MJ1_032
# 21              BLACK  AB18MJ1_032
# 22              BLACK  AB18MJ1_032
# 23              BLACK  AB18MJ1_032
# 24              BLACK  AB18MJ1_032
# 25              BLACK  AB18MJ1_032
# 26  MATTE BLACK BI-48  AB18MJ1_032
# 27  MATTE BLACK BI-48  AB18MJ1_032
# 28  MATTE BLACK BI-48  AB18MJ1_032
# 29              BLACK  AB18MJ1_032
# 30              BLACK  AB18MJ1_032
# 31              BLACK  AB18MJ1_032
# 32         GOLD/BLACK  AB18MJ1_032
# 33         BLACK/GOLD  AB18MJ1_032
# 34              BLACK  AB18MJ1_032
# 35         BLACK/GOLD  AB18MJ1_032
# 36        BLACK/WHITE  AB18MJ1_032
# 37   CAMEL 17-1019TPX  AB18MJ1_032
# 38         BLACK/GOLD  AB18MJ1_032
# 39                TBD  AB18MJ1_032
# 40                TBD  AB18MJ1_032
# 41              CLEAR  AB18MJ1_032
# 42                TBD  AB18MJ1_032
# 43                TBD  AB18MJ1_032
# 44                NaN          NaN
# 45                NaN          NaN

# %% [markdown]
# ## Walk through a dir
# * Check each xlsx in a dir
