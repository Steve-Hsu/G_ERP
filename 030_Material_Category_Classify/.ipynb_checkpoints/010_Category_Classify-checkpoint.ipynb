# %% [markdown]
# # Category_Classify
# ## Goal of the function
# * The dataSource of the func is M-List
# * Classify the material in the M-List, and fill the new colum "Category" with string such as "Fabric", "Zipper", "Button" etc.
# * Save the result as a Categoried_M_List

# %%
import pandas as pd
import numpy as np

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# File system
from os import walk
from os.path import join

# Switch area
CATEGORY_LIST =['fabric', 'insulation', 'interfacing', 'zipper', 'label']
SUBJECT = 'label'
VOCAB_SIZE = 900

# %%
FROM_DIR = 'DataSource/M-List'
TO_DIR = 'result'

# %%
 M_List = pd.read_csv(FROM_DIR + '/L1-106-17_HASTING_07_28_16_TRIMS_material_list.csv', encoding = 'ISO-8859-1')

# %% [markdown]
# * df.insert(1, 'Category', '', True)
#
# * df.at[0,'Category'] = 'Steve'

# %% [markdown]
# # Functions
# * We need to convert the M_list(Type in DF)through several process to Full matrix, so we can classify the M_List with the trained_data we made before.
# ## Process
# ### delete_col()
# ### stemmered_nltk_convert()
# ### turn_series()
# ### make_sparse_matrix()
# ### make_full_feature()

# %% [markdown]
# ## delete_col()
# * Delete the none columns

# %%
def delete_col(m_list):
    for col in m_list:
        if m_list[col].count() == 0:
            m_list = m_list.drop(col, axis = 1)
        
    return m_list

# %% [markdown]
# ## stemmered_nltk_convert()
# * Nltk stemmered Function

# %%
def stemmered_nltk_convert(col_of_df):
    '''
    Parameter of this function is a column of a dataFrame.
    
    '''
    # difine Stop words
    stop_words = set(stopwords.words('english'))
    # Difine Stemmer
    stemmer = SnowballStemmer('english')
    
    # converts to lower case and splits up the words
    words = word_tokenize(col_of_df)
    filtered_words = []
    
    for word in words:
        # Removes the stop words and punctuation
        # if word is not in the stop_words list and is not a alpha.
        if word not in stop_words and word.isalpha():
            filtered_words.append(stemmer.stem(word))
            
    return filtered_words

# %% [markdown]
# ## turn_series()
# #### Walk through bom
# * Parse a xlsm of bom, turn the row into a cell, all the cells will form a col.
# * Put the cell to the classify function
# * Return the index of row that is True

# %%
def turn_series(bom):
    '''
    
    The parameter of the func is a dataFrame
    
    '''
    database = []
    
    for row in bom.index:
        row_str = str()
        for col in bom:
            row_str = row_str + ', ' + str(bom.at[row, col])
        database.append(row_str)
    
    col = pd.Series(database)
#     index_list = classify_series(col)
    
    return col

# %% [markdown]
# ## make_sparse_matrix()
# ### Sparse Matrix Function
# * Create a sparse Matrix for the data we want to predict
# * The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.

# %%
def make_sparse_matrix(df, vocabulary):
    """
    Param1:
    The data we want to sparse, which must be in format of DataFrame.
    
    Param2:
    The vocabulary, it is generated when we training datas.
    
    Returns a sparse matrix as dataframe
    """
 
    indexed_words = pd.Index(vocabulary.VOCAB_WORD)
    nr_rows = df.shape[0]
    nr_cols = df.shape[1]
    word_set = set(indexed_words)
    dict_list = []
    
    for i in range(nr_rows):
        for j in range(nr_cols):
            
            word = df.iat[i, j]
            if word in word_set:
                doc_id = df.index[i]
                word_id = indexed_words.get_loc(word)
                
                item = {'MATERIAL_ID': doc_id,
                       'OCCURENCE': 1, 'WORD_ID': word_id}
                
                dict_list.append(item)
                
    return pd.DataFrame(dict_list)

# %% [markdown]
# ## make_full_feature()
# ### Full Matrix
# * Since we want to predict the data, so we create the Full Feature directly.

# %%
def make_full_feature(sparse_matrix, nr_words, doc_idx = 0, word_idx = 1, freq_idx = 2):
    column_names = ['MATERIAL_ID'] + list(range(0, VOCAB_SIZE))
    doc_id_names = np.unique(sparse_matrix[:,0])
    full_matrix = pd.DataFrame(index = doc_id_names, columns = column_names)
    full_matrix.fillna(value=0, inplace=True)
    
    for i in range(sparse_matrix.shape[0]):
        doc_nr = sparse_matrix[i][doc_idx]
        word_id = sparse_matrix[i][word_idx]
        occurrence = sparse_matrix[i][freq_idx]
        
        full_matrix.at[doc_nr, 'MATERIAL_ID'] = doc_nr
        full_matrix.at[doc_nr, word_id] = occurrence
        
    full_matrix.set_index('MATERIAL_ID', inplace = True)
    return full_matrix

# %% [markdown]
# # Core Funciton
# ## Material_Classifor
# * Classifor the materials in the M-List,
# * Mateiral is in row direction in a M-List.
# * Return a list of index of row that classified as "true"

# %%
def material_classifor(bom, 
                       VOCAB  = 'DataSource/Trained Data/' + SUBJECT + '_vocabulary.csv', 
                       TRAIN_DATA_1 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_1_in_train_data',
                       TRAIN_DATA_0 = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_ctg_0_in_train_data', 
                       TRAIN_DATA_ALL = 'DataSource/Trained Data/' + SUBJECT + '_prob_tokens_all_in_train_data', 
                       PROB_1_TRAIN_DATA = 'DataSource/Trained Data/' + SUBJECT + '_prob_ctg_1_in_train_data' ):
    '''
    Param_1
    <bom>
    DataFrame, by reading M-List in csv format.
    
    Param_2
    <VOCAB>
    The path of the vocabulary
    Token list with WORD_ID
    
    Param_3
    <TRAIN_DATA_1>
    The trained data of catagory True
    Probabilitie of each token in category True
    
    Param_4
    <TRAIN_DATA_0>
    The trained data of category False
    Probabilitie of each token in category False
    
    Param_5
    <TRAIN_DATA_ALL>
    The trained data of category both.
    Probabilitie of each token in all documents
    
    Param_6
    <PROB_1_TRAIN_DATA>
    The probability of documents in catagory True in all documents.
    Number of documents in catagory True / number of all documents
    '''
    # read the vocabulary
    vocab = pd.read_csv(VOCAB, index_col = 0)
    # read the trained_datas
    train_data_1 = np.loadtxt(TRAIN_DATA_1)
    train_data_0 = np.loadtxt(TRAIN_DATA_0)
    train_data_all = np.loadtxt(TRAIN_DATA_ALL)
    prob_ctg_1 = pd.read_csv(PROB_1_TRAIN_DATA, index_col = 0)
    prob_ctg_1_train_data = prob_ctg_1.loc[0, 'prob_ctg_1_train_set']
    
    
    # Delete useless cols
    col_deleted_bom = delete_col(bom)
    
    # Series
    # Parse the bom, make each col getting together to be 1 col
    new_bom = turn_series(col_deleted_bom)
    
    # nltk_convert
    stemmed_bom = new_bom.apply(stemmered_nltk_convert)
    
    # Convert the stemmed series into df
    # 1 token get 1 cell
    word_col_df = pd.DataFrame.from_records(stemmed_bom.tolist())
    
    # Sparse Matrix
    # Create a sparse Matrix for the data we want to predict
    # The difference of this function in comparition with Classification Model for Train data, is this function don't need CATEGORY.
    sparse_predict_df = make_sparse_matrix(word_col_df, vocab)
    # Grouped by MATERIAL_ID
    sparse_predict_df_grouped = sparse_predict_df.groupby(['MATERIAL_ID', 'WORD_ID']).sum()
    # Reset it index
    sparse_predict_df_grouped = sparse_predict_df_grouped.reset_index()
    # Convert it into numpy array.
    sparse_predict_data = sparse_predict_df_grouped.to_numpy()
    
    #Full Matrix
    predict_full_feature = make_full_feature(sparse_predict_data, vocab.shape[0])
    
    #Joint probability in log format
    joint_log_ctg_1 = predict_full_feature.dot(np.log(train_data_1) - np.log(train_data_all)) + np.log(prob_ctg_1_train_data)
    joint_log_ctg_0 = predict_full_feature.dot(np.log(train_data_0)-np.log(train_data_all))+np.log(1 - prob_ctg_1_train_data)
    # Prediction
    prediction_log = joint_log_ctg_1 > joint_log_ctg_0
    
    # Get the index of the row that predicted as material in the bom
    row_list = prediction_log[prediction_log == True].index
    
    #2020/03/11
    # The difference with the func "M-List_generator" is that the func only return a list of index classified as True.
    # Later I may optimize the func "M-List_generator" same as this func, so the two func can use same code as this func.
    # Let the different part be done outside the func.
#     # Get the material from the original bom by the index in row_list
#     material_list = bom.loc[row_list,:]
    
    return row_list

# %%
x = pd.read_csv('DataSource/M-List/L1-106-17_HASTING_07_28_16_TRIMS_material_list.csv', encoding = 'ISO-8859-1')

# %%
my_list = material_classifor(x)

# %%
my_list
# Out:
# Int64Index([33, 34, 35, 36], dtype='int64', name='MATERIAL_ID')

# %%
x
# Out:
#     MATERIAL_ID CATEGORY   0  \
# 0            10           10
# 1            13           13
# 2            14           14
# 3            15           15
# 4            18           18
# 5            20           20
# 6            21           21
# 7            24           24
# 8            25           25
# 9            26           26
# 10           29           29
# 11           30           30
# 12           33           33
# 13           36           36
# 14           37           37
# 15           40           40
# 16           41           41
# 17           42           42
# 18           43           43
# 19           44           44
# 20           45           45
# 21           48           48
# 22           49           49
# 23           50           50
# 24           51           51
# 25           52           52
# 26           55           55
# 27           56           56
# 28           57           57
# 29           58           58
# 30           59           59
# 31           65           65
# 32           68           68
# 33           69           69
# 34           70           70
# 35           71           71
# 36           72           72
# 37           73           73
#
#                                                     1  \
# 0                                        HAND POCKETS
# 1                                        CENTER FRONT
# 2                                        HAND POCKETS
# 3                                       INSIDE POCKET
# 4                                   FRONT LEFT SLEEVE
# 5                                          LOWER BODY
# 6                                          LEFT CHEST
# 7                             CF POWDER SKIRT CLOSURE
# 8   POW SKIRT: JACKET TO PANT CONNECTION ON POWDER...
# 9   "SNAP AWAY POWDER SKIRT" SNAP POWDER SKIRT TO ...
# 10                                 HEM HOOD CORD LOCK
# 11                                  HEM CORD LOCK TIP
# 12                               HEM ADJUST CORD EXIT
# 13                                               HEM
# 14                                               HOOD
# 15                     KEYCLIP LOOP RIGHT HAND POCKET
# 16                            HEM CORD LOCK TIE DOWNS
# 17                                  RIGHT HAND POCKET
# 18             JACKET TO PANT CONNECTION CENTER BACK
# 19             JACKET TO PANT CONNECTION AT SIDE TABS
# 20                                   INNER POCKET TAB
# 21                       POWDER SKIRT GRIPPER ELASTIC
# 22          JACKET TO PANT CONNECTION CENTER BACK TAB
# 23                                      GOGGLE POCKET
# 24                    LINING MEDIA POCKET CABLE GUIDE
# 25                      ENCASED IN BACK OF SLEEVE HEM
# 26                                              CUFF
# 27                                           CUFF TAB
# 28                                         CF PLACKET
# 29                          HAND & CHEST POCKET FLAPS
# 30                                       MEDIA POCKET
# 31                         SLEEVE GAITER COVER STITCH
# 32                       LEFT HAND POCKET ZIPPER HEAD
# 33                                   LINING CB FACING
# 34                              LINING LEFT SIDE SEAM
# 35                              LINING LEFT SIDE SEAM
# 36                              LINING LEFT SIDE SEAM
# 37           FRONT LEFT BELT LOOP TO ATTACH HANG TAGS
#
#                                                     2  \
# 0                                             #5 COIL
# 1                        L1 SNAP ON METAL ZIPPER PULL
# 2                                    SELF FABRIC PULL
# 3                                    SELF FABRIC PULL
# 4                                 L1 SMALL EMBROIDERY
# 5                                             L1 SNAP
# 6                      L1 FAUX LEATHER TRIANGLE PATCH
# 7                   14 MM PLASTIC SNAP 24L METAL SNAP
# 8                   14 MM PLASTIC SNAP 24L METAL SNAP
# 9                   14 MM PLASTIC SNAP 24L METAL SNAP
# 10                                          CORD LOCK
# 11                                      CORD TIP BEAD
# 12                       SMALL: GROMMET  8mm diameter
# 13                              3mm STRETCH SHOCKCORD
# 14                           8mm ROUND WOVEN DRAWCORD
# 15                            1/4" FLAT X 1 3/4" LOOP
# 16                             3/8" FLAT WEBBING LOOP
# 17                                   PLASTIC KEYCLIP
# 18                        3/4" X 1" 1" X 1" FINISHED
# 19  3/4" X  3 1/2" 3 1/4" FLAT WEBBING (FINISHED L...
# 20                                               3/4"
# 21                                               25mm
# 22            FLAT ELASTIC TAPE 3/4" x 4 1/4" 1" X 4"
# 23                                   ELASTINE BINDING
# 24                                  1/4" FLAT ELASTIC
# 25                                                NaN
# 26                                        2.5cm X 9cm
# 27                                      2.5cm X 6.5cm
# 28                                         1/2" X 3"
# 29                                         1/2" X 2"
# 30                                          1/2" X 3"
# 31                             MUST BE STRETCH THREAD
# 32                                        L1 HANG TAG
# 33       WP BREATH / SIZE LABEL / RN CA / MADE IN ___
# 34                                      ADDRESS LABEL
# 35                                      CONTENT LABEL
# 36                                      WASHING LABEL
# 37                                      CLEAR ZIP TIE
#
#                                                     3  \
# 0         DADHR DIECAST WIRE (NON YKK) AUTO NON LOCK
# 1   SHENZHEN GUAN HONG METAL ZIPPER CO.  / L1-2016...
# 2                           FACTORY MADE // 11NT-045
# 3                           FACTORY MADE // 11NT-045
# 4                                SOLUNA / L1-2016-026
# 5                             LUKS / L1-2016-TRIM-002
# 6              YIQING SHOE FACTORY / L1-2017-TRIM-102
# 7                                     DURAFLEX / 1414
# 8                                     DURAFLEX / 1414
# 9                                     DURAFLEX / 1414
# 10                                       KNK / SP-177
# 11                                  KNK / CS-074 ZP20
# 12                                       PLEASE SORCE
# 13                                SUPPLER / REF NUBER
# 14                              SUNSUN / SV160218-1 A
# 15                                SUPPLER / REF NUBER
# 16                                SUPPLER / REF NUBER
# 17                                SUPPLER / REF NUBER
# 18                                SUPPLER / REF NUBER
# 19                                SUPPLER / REF NUBER
# 20                                SUPPLER / REF NUBER
# 21                                SUPPLER / REF NUBER
# 22                                SUPPLER / REF NUBER
# 23                                SUPPLER / REF NUBER
# 24                                SUPPLER / REF NUBER
# 25                                SUPPLER / REF NUBER
# 26                                  PAIHO / Loop#1057
# 27                                   PAIHO / HookETN7
# 28                       PAIHO / HookETN7 / Loop#1057
# 29                       PAIHO / HookETN7 / Loop#1057
# 30                       PAIHO / HookETN7 / Loop#1057
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                        SEW AS LOOP
# 35                                        SEW AS LOOP
# 36                                        SEW AS LOOP
# 37                                       SUPPLIER //
#
#                            4  \
# 0             1 PER SIDE = 2
# 1                          1
# 2             1 PER SIDE = 2
# 3                          1
# 4                          1
# 5                          2
# 6                          1
# 7           4 MALE, 2 FEMALE
# 8                     3 SETS
# 9           1 MALE, 1 FEMALE
# 10            1 PER SIDE = 2
# 11            1 PER SIDE = 2
# 12            2 PER SIDE = 4
# 13                       NaN
# 14                       NaN
# 15                         1
# 16            1 PER SIDE = 2
# 17                         1
# 18  TAB BEHIND EACH SNAP = 2
# 19                         1
# 20                         1
# 21                         1
# 22                         1
# 23                         1
# 24                         1
# 25                         1
# 26                1 LOOP TAB
# 27                1 HOOK TAB
# 28                    2 SETS
# 29   2 SETS  PER POCKET FLAP
# 30                  2 PIECES
# 31                       NaN
# 32                         1
# 33                         1
# 34                         1
# 35                         1
# 36                         1
# 37                         1
#
#                                                     5  \
# 0   SILDER/PULL COLOR: PSEUDO ANTI SILVER / TEETH ...
# 1                                 PSEUDO ANTI SILVER
# 2                               SHELL FABRIC MATCHING
# 3                               SHELL FABRIC MATCHING
# 4                                                 DTM
# 5                            PSEUDO ANTI SILVER/BLACK
# 6                                               BLACK
# 7            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 8            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 9            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 10                                              BLACK
# 11                                              BLACK
# 12                                PSEUDO ANTI SILVER
# 13                                              BLACK
# 14                                              BLACK
# 15                                              BLACK
# 16                                              BLACK
# 17                                              BLACK
# 18                                              BLACK
# 19                                              BLACK
# 20                                              BLACK
# 21                                         BLACK/GREY
# 22                                              BLACK
# 23                                              BLACK
# 24                                              BLACK
# 25                                              STOCK
# 26                                           MATCHING
# 27                                           MATCHING
# 28                                           MATCHING
# 29                                           MATCHING
# 30                                           MATCHING
# 31                                           MATCHING
# 32                                        L1 HANG TAG
# 33                                                NaN
# 34                                      ADDRESS LABEL
# 35                                      CONTENT LABEL
# 36                                      WASHING LABEL
# 37                                      CLEAR ZIP TIE
#
#                                                     6  \
# 0   SILDER/PULL COLOR: PSEUDO ANTI SILVER / TEETH ...
# 1                                 PSEUDO ANTI SILVER
# 2                               SHELL FABRIC MATCHING
# 3                               SHELL FABRIC MATCHING
# 4                                                 DTM
# 5                            PSEUDO ANTI SILVER/BLACK
# 6                                               BLACK
# 7            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 8            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 9            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 10                                              BLACK
# 11                                              BLACK
# 12                                PSEUDO ANTI SILVER
# 13                                              BLACK
# 14                                  19-4006 TPX BLACK
# 15                                              BLACK
# 16                                              BLACK
# 17                                              BLACK
# 18                                              BLACK
# 19                                              BLACK
# 20                                              BLACK
# 21                                         BLACK/GREY
# 22                                              BLACK
# 23                                              BLACK
# 24                                              BLACK
# 25                                              STOCK
# 26                                           MATCHING
# 27                                           MATCHING
# 28                                           MATCHING
# 29                                           MATCHING
# 30                                           MATCHING
# 31                                           MATCHING
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
#
#                                                     7  \
# 0   SILDER/PULL COLOR: PSEUDO ANTI SILVER / TEETH ...
# 1                                 PSEUDO ANTI SILVER
# 2                               SHELL FABRIC MATCHING
# 3                               SHELL FABRIC MATCHING
# 4                                                 DTM
# 5                            PSEUDO ANTI SILVER/BLACK
# 6                                               BLACK
# 7            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 8            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 9            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE
# 10                                              BLACK
# 11                                              BLACK
# 12                                PSEUDO ANTI SILVER
# 13                                              BLACK
# 14                                   16-0906 TPX SAND
# 15                                              BLACK
# 16                                              BLACK
# 17                                              BLACK
# 18                                              BLACK
# 19                                              BLACK
# 20                                              BLACK
# 21                                         BLACK/GREY
# 22                                              BLACK
# 23                                              BLACK
# 24                                              BLACK
# 25                                              STOCK
# 26                                           MATCHING
# 27                                           MATCHING
# 28                                           MATCHING
# 29                                           MATCHING
# 30                                           MATCHING
# 31                                           MATCHING
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
#
#                                                     8            9
# 0   SILDER/PULL COLOR: PSEUDO ANTI SILVER / TEETH ...          NaN
# 1                                 PSEUDO ANTI SILVER           NaN
# 2                               SHELL FABRIC MATCHING          NaN
# 3                               SHELL FABRIC MATCHING          NaN
# 4                                                 DTM          NaN
# 5                            PSEUDO ANTI SILVER/BLACK          NaN
# 6                                               BLACK          NaN
# 7            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE          NaN
# 8            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE          NaN
# 9            MATTE BLACK CAP/ PSEUDO ANTI SILVER BASE          NaN
# 10                                              BLACK          NaN
# 11                                              BLACK          NaN
# 12                                PSEUDO ANTI SILVER           NaN
# 13                                              BLACK          NaN
# 14                                18-0950TPX  HARVEST          NaN
# 15                                              BLACK          NaN
# 16                                              BLACK          NaN
# 17                                              BLACK          NaN
# 18                                              BLACK          NaN
# 19                                              BLACK          NaN
# 20                                              BLACK          NaN
# 21                                         BLACK/GREY          NaN
# 22                                              BLACK          NaN
# 23                                              BLACK          NaN
# 24                                              BLACK          NaN
# 25                                              STOCK          NaN
# 26                                           MATCHING  ROUND EDGES
# 27                                           MATCHING          NaN
# 28                                           MATCHING          NaN
# 29                                           MATCHING          NaN
# 30                                           MATCHING          NaN
# 31                                           MATCHING          NaN
# 32                                                NaN          NaN
# 33                                                NaN          NaN
# 34                                                NaN          NaN
# 35                                                NaN          NaN
# 36                                                NaN          NaN
# 37                                                NaN          NaN

# %% [markdown]
# # Main Funciton
# ## Loop through materials designated as category.
# * Analyze a M-List with several sets of train-data and vocabulary.
# * Each set of trainned-data and vocabulary represents 1 category of material, such as fabric, zipper, label.
# * This func will feed the func "material_classifor" each set of trainned-data and vocabulary by order.

# %%
M = 'DataSource/M-List/L1-106-17_HASTING_07_28_16_TRIMS_material_list.csv'

# %%
def fill_out_col_category(M_list, LIST = CATEGORY_LIST,) :
    '''
    Param_1
    <M_list>
    M_list in CSV format
    The func will turn it into a DataFrame while calculating.
    
    '''
    bom = pd.read_csv(M_list, encoding = 'ISO-8859-1')
    bom.insert(1, 'CATEGORY', '', True)
    return bom

# %% [markdown]
# ## Walk through a dir
# * Check each xlsx in a dir
